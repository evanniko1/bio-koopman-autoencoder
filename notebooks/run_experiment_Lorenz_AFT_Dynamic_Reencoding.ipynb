# %% [markdown]
# # Koopman Operator Training with Autoencoder
#
# This notebook implements a training pipeline for a Koopman operator model combined with an autoencoder. The code includes data loading, model definition, training, and visualization of results such as trajectories and eigenvalues.

# %%
import os
# Move up one directory to make sure the script can find the modules and save files in the correct place
os.chdir('..')
# Verify the current working directory
print(os.getcwd())

import argparse
import json
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, Dataset
import torch.nn.init as init
import torch.multiprocessing as mp

# Import local modules (assuming these are available in your environment)
from utils.tools import set_seed, get_device
from utils.config_args import get_args
from utils.Viz import *
from KoopmanTrainer_AFT_DR import Trainer
from data_handler import KoopmanDataHandler
from models.autoencoder import AutoEncoder
from models.efficient_kan import *
from models.koopman_operator import Knet
from models.AFT import AttentionFreeTransformer

# Set multiprocessing start method
try:
    mp.set_start_method('spawn')
except RuntimeError:
    pass  # method already set

# Disable deterministic algorithms for flexibility
torch.use_deterministic_algorithms(False)
# Out:
# /Users/mohammedahmed/Desktop/Project/KoopKAN/Clean Code/bio-koopman-autoencoder

# %% [markdown]
# ## Training Settings
#
# Configure the training settings, including random seeds for reproducibility and device selection (CUDA or CPU).

# %%
# the version of pandas
def get_pandas_version():
    import numpy as np
    import pandas as pd
    return pd.__version__
print(f"Pandas version: {get_pandas_version()}")
import numpy as np
print(f"NumPy version: {np.__version__}")
# Out:
# Pandas version: 2.2.2
# NumPy version: 2.0.1

# %%
# Get arguments (assuming get_args() handles command-line or default args)
args = get_args()

# Set seeds for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.cuda.manual_seed(args.seed)
torch.manual_seed(args.seed)
np.random.seed(args.seed)
set_seed(args.seed)

# Device configuration
device = get_device()
# Out:
# Using the CPU

# %%
# editing the args 
# in this experiement we increased the timesteps to 201 and the time to 40 which is double the original experiment to make sure we would capture the limit cycle 
args.dataset = 'Lorenz'
args.folder = 'Lorenz_AFT_Dynamic_Reencoding'
args.time_steps = 1001
args.prediction_length = 40
args.max_time = 40
args.num_samples = 2000
args.bottleneck = 100
args.decoder_loss_weight = .1
args.lr = 1e-3
args.epochs = 50
args.loss_function = 'mse'
args.unitary_loss_weight = 10
args.context_length = 20
args.load_from_checkpoint = False
#args.batch_size = 265

# %% [markdown]
# ## Create Experiment Folder
#
# Set up the folder structure to save experiment results, including arguments in a JSON file.

# %%
# Create experiment folder
experiment_folder = 'experiments'
if not os.path.isdir(experiment_folder):
    os.mkdir(experiment_folder)

folder_path = os.path.join(experiment_folder, args.folder)
os.makedirs(folder_path, exist_ok=True)

# Save arguments to JSON
args_dict = vars(args)
with open(os.path.join(folder_path, 'args.json'), 'w') as f:
    json.dump(args_dict, f,indent=2)

# %% [markdown]
# ## Load and Prepare Dataset
#
# Load and preprocess the dataset using the `KoopmanDataHandler` class, then create data loaders for training, validation, and testing.

# %%
# Convert args to a dictionary for the data handler

config = {
    "dataset": args.dataset,
    "data_dir": args.data_dir,
    "train_size": args.train_size,
    "val_size": args.val_size,
    "batch_size": args.batch_size,
    "noise": args.noise,
    "orthogonal_projection": args.orthogonal_projection,
    "num_combinations": args.num_combinations,
    "num_samples": args.num_samples,
    "time_steps": args.time_steps,
    "max_time": args.max_time,
    "normalize": args.normalize,
    "prediction_length": args.prediction_length,
    "stride": args.stride,
    "device": device,
    "theta": args.theta
}

# Initialize data handler
data_handler = KoopmanDataHandler(config)
data_handler.load_data()
preprocessed_data = data_handler.preprocess()
dataloaders = data_handler.create_dataloaders()

train_loader = dataloaders["train"]
val_loader = dataloaders["val"]
test_loader = dataloaders["test"]

# Get data dimensions for model initialization
input_size = preprocessed_data['Xtrain'].shape[-1]
# Out:
# 100%|██████████| 2000/2000 [00:00<00:00, 25940.00it/s]
# the shape of the data is torch.Size([2000, 1001, 3])
# Processing dataset: Lorenz
# train_idx: 1600, val_idx: 1800
# Processed data shapes - Train: torch.Size([1600, 1001, 3]), Val: torch.Size([200, 1001, 3]), Test: torch.Size([200, 1001, 3])
# /Users/mohammedahmed/Desktop/Project/KoopKAN/Clean Code/bio-koopman-autoencoder/data_handler.py:151: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Xtrain = torch.tensor(Xtrain, dtype=torch.float32).to(self.device)
# /Users/mohammedahmed/Desktop/Project/KoopKAN/Clean Code/bio-koopman-autoencoder/data_handler.py:152: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Xval = torch.tensor(Xval, dtype=torch.float32).to(self.device)
# /Users/mohammedahmed/Desktop/Project/KoopKAN/Clean Code/bio-koopman-autoencoder/data_handler.py:153: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Xtest = torch.tensor(Xtest, dtype=torch.float32).to(self.device)

# %% [markdown]
# ## Model Definition
#
# Define the autoencoder (`AutoEncoder`) and Koopman operator (`Knet`), then combine them into a `ModuleDict`.

# %%
# Model definition
ae = AutoEncoder(
    input_size=input_size,
    encoded_size=args.bottleneck,
    encoder_hidden_layers=args.encoder_hidden_layers,
    decoder_hidden_layers=args.decoder_hidden_layers,
    network_type=args.network_type,
    batch_norm=False
)
knet = Knet(size=args.bottleneck)

AFT = AttentionFreeTransformer(d_model=args.bottleneck, max_seq_len=args.context_length, device=device)

# Combine AE and Knet as a ModuleDict
model = torch.nn.ModuleDict({'ae': ae, 'knet': knet,'aft_layer': AFT})
model = model.to(device)

# %% [markdown]
# ## Model Summary
#
# Display the total number of parameters and the model architecture.

# %%
print('**** Setup ****')
print('Total params: %.2fM' % (sum(p.numel() for p in model.parameters())/1000000.0))
print('Total params: %.2fk' % (sum(p.numel() for p in model.parameters())/1000.0))
print('************')

print('**** Model Architecture ****')
print(model)
print('***************************')
# Out:
# **** Setup ****
# Total params: 0.08M
# Total params: 81.80k
# ************
# **** Model Architecture ****
# ModuleDict(
#   (ae): AutoEncoder(
#     (encoder): Sequential(
#       (0): MLP(
#         (net): ModuleList(
#           (0): Linear(in_features=3, out_features=100, bias=True)
#           (1): LeakyReLU(negative_slope=0.01)
#           (2): Linear(in_features=100, out_features=100, bias=True)
#           (3): LeakyReLU(negative_slope=0.01)
#           (4): Linear(in_features=100, out_features=100, bias=True)
#         )
#       )
#       (1): Dropout(p=0.3, inplace=False)
#     )
#     (decoder): MLP(
#       (net): ModuleList(
#         (0): Linear(in_features=100, out_features=100, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): Linear(in_features=100, out_features=100, bias=True)
#         (3): LeakyReLU(negative_slope=0.01)
#         (4): Linear(in_features=100, out_features=3, bias=True)
#       )
#     )
#   )
#   (knet): Knet(
#     (net): Linear(in_features=100, out_features=100, bias=False)
#   )
#   (aft_layer): AttentionFreeTransformer(
#     (Wq): Linear(in_features=100, out_features=100, bias=True)
#     (Wk): Linear(in_features=100, out_features=100, bias=True)
#     (Wv): Linear(in_features=100, out_features=100, bias=True)
#   )
# )
# ***************************

# %% [markdown]
# ## Load from Checkpoint
#
# Optionally load a pre-trained model from a checkpoint if specified.

# %%
if args.load_from_checkpoint:
    checkpoint_path = os.path.join(folder_path, 'model.pkl')
    if os.path.isfile(checkpoint_path):
        model.load_state_dict(torch.load(checkpoint_path))
        print(f'Model loaded from {checkpoint_path}')
    else:
        print(f'No checkpoint found at {checkpoint_path}')

# %% [markdown]
# ## Training
#
# Train the model using the `Trainer` class with the specified data loaders.

# %%
trainer = Trainer(model, args, device, do_eval=True, train_loader=train_loader, val_loader=val_loader)
# Out:
# Using the CPU

# %%
trainer.train_KoopmanAE()
# Out:
# Training Epochs:  10%|█         | 5/50 [18:47<2:46:57, 222.61s/it]
# Epoch 5/50
# Training - Recon Loss: 5.290302e-04, Linear Loss: 6.449922e-05, Pred Loss: 7.260829e-03, Unitary Loss: 3.381349e-06, Total Loss: 8.772986e-04
# Validation - Recon Loss: 1.132499e-04, Linear Loss: 3.837070e-05, Pred Loss: 6.362212e-03,Unitary Loss: 2.930955e-06, Total Loss: 6.859170e-04
# Training Epochs:  20%|██        | 10/50 [38:02<2:33:29, 230.23s/it]
# Epoch 10/50
# Training - Recon Loss: 4.482412e-04, Linear Loss: 6.324212e-05, Pred Loss: 5.320106e-03, Unitary Loss: 3.265353e-06, Total Loss: 6.727304e-04
# Validation - Recon Loss: 1.051654e-04, Linear Loss: 3.615147e-05, Pred Loss: 4.441513e-03,Unitary Loss: 4.310225e-06, Total Loss: 4.908194e-04
# Training Epochs:  30%|███       | 15/50 [57:27<2:15:34, 232.43s/it]
# Epoch 15/50
# Training - Recon Loss: 4.279396e-04, Linear Loss: 6.303120e-05, Pred Loss: 4.311120e-03, Unitary Loss: 3.242480e-06, Total Loss: 5.693620e-04
# Validation - Recon Loss: 1.385374e-04, Linear Loss: 3.940044e-05, Pred Loss: 3.914108e-03,Unitary Loss: 2.860069e-06, Total Loss: 4.446650e-04
# Training Epochs:  40%|████      | 20/50 [1:16:51<1:56:22, 232.75s/it]
# Epoch 20/50
# Training - Recon Loss: 3.956633e-04, Linear Loss: 5.957209e-05, Pred Loss: 3.731806e-03, Unitary Loss: 3.573259e-06, Total Loss: 5.080516e-04
# Validation - Recon Loss: 1.284530e-04, Linear Loss: 3.551251e-05, Pred Loss: 2.792873e-03,Unitary Loss: 3.508785e-06, Total Loss: 3.276452e-04
# Training Epochs:  50%|█████     | 25/50 [1:36:15<1:36:55, 232.62s/it]
# Epoch 25/50
# Training - Recon Loss: 3.689607e-04, Linear Loss: 5.559452e-05, Pred Loss: 3.400097e-03, Unitary Loss: 3.665948e-06, Total Loss: 4.691598e-04
# Validation - Recon Loss: 1.269167e-04, Linear Loss: 3.217608e-05, Pred Loss: 2.158237e-03,Unitary Loss: 4.044606e-06, Total Loss: 2.606915e-04
# Training Epochs:  60%|██████    | 30/50 [1:55:38<1:17:32, 232.61s/it]
# Epoch 30/50
# Training - Recon Loss: 3.363831e-04, Linear Loss: 5.062330e-05, Pred Loss: 3.115595e-03, Unitary Loss: 3.538080e-06, Total Loss: 4.312019e-04
# Validation - Recon Loss: 7.039444e-05, Linear Loss: 3.245587e-05, Pred Loss: 2.558895e-03,Unitary Loss: 3.006526e-06, Total Loss: 2.953849e-04
# Training Epochs:  70%|███████   | 35/50 [2:15:05<58:19, 233.32s/it]
# Epoch 35/50
# Training - Recon Loss: 3.139632e-04, Linear Loss: 4.498101e-05, Pred Loss: 2.725583e-03, Unitary Loss: 3.035341e-06, Total Loss: 3.792891e-04
# Validation - Recon Loss: 1.046387e-04, Linear Loss: 2.761192e-05, Pred Loss: 2.311219e-03,Unitary Loss: 2.647800e-06, Total Loss: 2.691977e-04
# Training Epochs:  80%|████████  | 40/50 [2:34:29<38:44, 232.40s/it]
# Epoch 40/50
# Training - Recon Loss: 2.967487e-04, Linear Loss: 4.266665e-05, Pred Loss: 2.691589e-03, Unitary Loss: 2.996974e-06, Total Loss: 3.714702e-04
# Validation - Recon Loss: 1.062671e-04, Linear Loss: 2.530570e-05, Pred Loss: 2.074140e-03,Unitary Loss: 3.471016e-06, Total Loss: 2.433464e-04
# Training Epochs:  90%|█████████ | 45/50 [2:53:51<19:22, 232.51s/it]
# Epoch 45/50
# Training - Recon Loss: 2.766067e-04, Linear Loss: 3.969969e-05, Pred Loss: 2.479832e-03, Unitary Loss: 2.848080e-06, Total Loss: 3.438244e-04
# Validation - Recon Loss: 1.040299e-04, Linear Loss: 2.579395e-05, Pred Loss: 3.480731e-03,Unitary Loss: 2.807393e-06, Total Loss: 3.842700e-04
# Training Epochs: 100%|██████████| 50/50 [3:12:58<00:00, 231.56s/it]
# Epoch 50/50
# Training - Recon Loss: 2.666709e-04, Linear Loss: 3.865331e-05, Pred Loss: 2.457305e-03, Unitary Loss: 3.134319e-06, Total Loss: 3.423941e-04
# Validation - Recon Loss: 8.670787e-05, Linear Loss: 2.266287e-05, Pred Loss: 2.060307e-03,Unitary Loss: 2.299776e-06, Total Loss: 2.373644e-04
# (ModuleDict(
#    (ae): AutoEncoder(
#      (encoder): Sequential(
#        (0): MLP(
#          (net): ModuleList(
#            (0): Linear(in_features=3, out_features=100, bias=True)
#            (1): LeakyReLU(negative_slope=0.01)
#            (2): Linear(in_features=100, out_features=100, bias=True)
#            (3): LeakyReLU(negative_slope=0.01)
#            (4): Linear(in_features=100, out_features=100, bias=True)
#          )
#        )
#        (1): Dropout(p=0.3, inplace=False)
#      )
#      (decoder): MLP(
#        (net): ModuleList(
#          (0): Linear(in_features=100, out_features=100, bias=True)
#          (1): LeakyReLU(negative_slope=0.01)
#          (2): Linear(in_features=100, out_features=100, bias=True)
#          (3): LeakyReLU(negative_slope=0.01)
#          (4): Linear(in_features=100, out_features=3, bias=True)
#        )
#      )
#    )
#    (knet): Knet(
#      (net): Linear(in_features=100, out_features=100, bias=False)
#    )
#    (aft_layer): AttentionFreeTransformer(
#      (Wq): Linear(in_features=100, out_features=100, bias=True)
#      (Wk): Linear(in_features=100, out_features=100, bias=True)
#      (Wv): Linear(in_features=100, out_features=100, bias=True)
#    )
#  ),
#  AdamW (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      capturable: False
#      differentiable: False
#      eps: 1e-08
#      foreach: None
#      fused: None
#      lr: 0.0008
#      maximize: False
#      weight_decay: 0.0
#  ),
#  {'recon_loss_tr': [0.008978200125539253,
#    0.0007194669946236685,
#    0.0006467923721910035,
#    0.0005582824341778736,
#    0.0005290302168652297,
#    0.0004989631749621143,
#    0.00046968168951719763,
#    0.0004742466213260465,
#    0.00045871283026254427,
#    0.0004482411877281916,
#    0.0004326564479454126,
#    0.0004328815253472295,
#    0.00043908363651148024,
#    0.0004261249382333003,
#    0.00042793960232412613,
#    0.00043022306766152713,
#    0.00041808950547024776,
#    0.0004022811691406162,
#    0.00039740083912110773,
#    0.0003956633227759788,
#    0.0003873990042865598,
#    0.0003900390540319569,
#    0.0003705088130254953,
#    0.0003701931064816031,
#    0.00036896071751965,
#    0.0003633515443652868,
#    0.00035942910667196415,
#    0.00034807394000183875,
#    0.0003353383738180093,
#    0.00033638313652191773,
#    0.0003341580642544971,
#    0.00030162539832426395,
#    0.00029713945156826187,
#    0.0002932902664030209,
#    0.0003139632058511384,
#    0.00029481516350596287,
#    0.0002884260167147571,
#    0.00031149672818914676,
#    0.0002846342206303292,
#    0.0002967486645339783,
#    0.00028428717679269733,
#    0.00028768470068239033,
#    0.0002700652617618245,
#    0.00027488439000574664,
#    0.0002766067280059163,
#    0.0002715897945089849,
#    0.0002774548747620661,
#    0.00027007558274256904,
#    0.00027196373540005044,
#    0.0002666709120028292],
#   'lin_loss_tr': [0.00032250945468041925,
#    8.154079574588002e-05,
#    6.173172387613962e-05,
#    6.041649023315292e-05,
#    6.44992155525216e-05,
#    6.30211838224074e-05,
#    6.298622124210616e-05,
#    6.443673524240883e-05,
#    6.367150479944397e-05,
#    6.324211813588686e-05,
#    6.206532473119493e-05,
#    6.256003589529288e-05,
#    6.277374836754578e-05,
#    6.25513893262574e-05,
#    6.303120350179533e-05,
#    6.360946563784756e-05,
#    6.342937863177467e-05,
#    6.202153935491036e-05,
#    6.094527296331777e-05,
#    5.9572091955057804e-05,
#    5.904187759306035e-05,
#    5.824570252560823e-05,
#    5.787921538820101e-05,
#    5.620896725873716e-05,
#    5.5594524133302566e-05,
#    5.450006404697461e-05,
#    5.414151422383365e-05,
#    5.27245643438575e-05,
#    5.1528226973146006e-05,
#    5.0623302642064844e-05,
#    5.044062827756932e-05,
#    4.742405700074069e-05,
#    4.62392395863067e-05,
#    4.483741527153982e-05,
#    4.498101122318038e-05,
#    4.3801613409219445e-05,
#    4.2975797322478306e-05,
#    4.3631080862918733e-05,
#    4.264270843448528e-05,
#    4.266665279738807e-05,
#    4.198088457526344e-05,
#    4.1904871355922235e-05,
#    4.0715461243137406e-05,
#    3.9831113645631356e-05,
#    3.969968668660878e-05,
#    3.921649504873973e-05,
#    3.9062028804800646e-05,
#    3.882791216469581e-05,
#    3.909525245447798e-05,
#    3.865330681394854e-05],
#   'pred_loss_tr': [0.021723620822659124,
#    0.010764664421363855,
#    0.008857992404815964,
#    0.0079133105062591,
#    0.007260828958854031,
#    0.006563939787923528,
#    0.0061654634163759575,
#    0.00593531335712955,
#    0.005598299289360262,
#    0.005320106487209424,
#    0.005159758257504089,
#    0.004856499886443725,
#    0.004864354163390427,
#    0.004519198004293223,
#    0.004311120464874152,
#    0.004325445344933449,
#    0.004015770420200004,
#    0.0038830653270379234,
#    0.0038380810809425844,
#    0.003731805998564195,
#    0.003610263244225123,
#    0.0037083327576827507,
#    0.0034127477411412823,
#    0.0034332253435364786,
#    0.0034000969334942893,
#    0.00323642586051418,
#    0.0032965987143419185,
#    0.003186571617095996,
#    0.003070358564473165,
#    0.0031155950252930767,
#    0.0030463707507602847,
#    0.002738372738154742,
#    0.0026536390026168414,
#    0.0026717422791896536,
#    0.0027255830641377704,
#    0.002578454092888834,
#    0.002583931239259343,
#    0.0028341657715662124,
#    0.0024910699873686598,
#    0.002691589330825895,
#    0.002598373796984244,
#    0.0026320298153984425,
#    0.0023950183174212855,
#    0.002415826894155445,
#    0.0024798320009025,
#    0.0025102932500048946,
#    0.0024043048565356305,
#    0.002439282901106051,
#    0.002465419037216983,
#    0.0024573047710106538],
#   'total_loss_tr': [0.007196301909776541,
#    0.001375032449550272,
#    0.0010438398835576547,
#    0.0009380427059738304,
#    0.0008772986345201398,
#    0.0008005018315513056,
#    0.0007598264992368012,
#    0.0007387794814215372,
#    0.0007024942951190609,
#    0.0006727304386968811,
#    0.0006553856985116848,
#    0.0006239333034927448,
#    0.000630714004106534,
#    0.0005909796658577546,
#    0.0005693620253248682,
#    0.0005756675903782094,
#    0.0005403467879508631,
#    0.0005250781020982721,
#    0.0005189106734015774,
#    0.0005080516056972928,
#    0.0004938053216944381,
#    0.0005058552558420779,
#    0.00047061758381076535,
#    0.000472264344184347,
#    0.00046915978177661856,
#    0.00044859777687834547,
#    0.0004555657338618804,
#    0.0004415450425753102,
#    0.00042543475893281474,
#    0.000431201919580783,
#    0.000422833373858638,
#    0.0003793020737349999,
#    0.00036871148403153754,
#    0.0003684180864105418,
#    0.000379289054187586,
#    0.0003575138037205308,
#    0.00035803166137950214,
#    0.0003907281583503853,
#    0.00034743651799588334,
#    0.00037147018944282237,
#    0.0003614049409880651,
#    0.00036475807781697223,
#    0.00033447064032343725,
#    0.0003355081894616492,
#    0.0003438243738129384,
#    0.0003470894044671303,
#    0.0003352794672467392,
#    0.00033960995923976205,
#    0.0003430674191208753,
#    0.0003423940569527608],
#   'recon_loss_va': [0.0005043137047323398,
#    0.00022618812508881092,
#    0.00027291230981063563,
#    0.0001623822026886046,
#    0.00011324992192385253,
#    0.0003305986305349506,
#    0.00020321504962339532,
#    0.00013580054055637448,
#    0.00032000303835957313,
#    0.00010516537331568543,
#    0.0001750344854372088,
#    0.00015778307788423264,
#    0.00016902579554880503,
#    0.00020896913229080384,
#    0.00013853737800673116,
#    0.00018521410711400677,
#    0.0001533963961264817,
#    0.00010492701494513312,
#    0.0001825484276196221,
#    0.00012845296587329357,
#    8.794256409601075e-05,
#    0.00014302896943263477,
#    0.00015617771459801587,
#    0.0001390092465953785,
#    0.00012691674201050773,
#    0.00023239840411406476,
#    0.00010472239046066534,
#    0.0003614013170590624,
#    9.232487591361859e-05,
#    7.039443744361051e-05,
#    0.00011263364049227676,
#    9.444718907616333e-05,
#    7.612563003931428e-05,
#    7.124034154912807e-05,
#    0.00010463869402883574,
#    6.528435524160159e-05,
#    9.89496609690832e-05,
#    0.00010151532569580013,
#    0.00010188998767262092,
#    0.000106267065530119,
#    8.641225977044087e-05,
#    0.00011080635777034331,
#    8.035086302697892e-05,
#    8.203649922506883e-05,
#    0.0001040298640873516,
#    0.00014163851883495227,
#    8.222185333579546e-05,
#    0.00012788166604877916,
#    8.370958830710152e-05,
#    8.670787065057084e-05],
#   'lin_loss_va': [5.2196129581716376e-05,
#    3.5844997546519154e-05,
#    3.367875410731358e-05,
#    3.4904031417681834e-05,
#    3.8370701349776934e-05,
#    3.83049115043832e-05,
#    3.764598041016143e-05,
#    3.584591895560152e-05,
#    3.509160542307655e-05,
#    3.6151474068901736e-05,
#    4.0741572229308075e-05,
#    3.718833531820565e-05,
#    3.9358386038657046e-05,
#    3.872483030136209e-05,
#    3.94004429836059e-05,
#    4.194543525954941e-05,
#    3.840596555164666e-05,
#    3.7086522661411435e-05,
#    3.9478770213463575e-05,
#    3.551251247699838e-05,
#    3.8663231771352e-05,
#    3.6357844328449575e-05,
#    3.166204564877262e-05,
#    3.516775977914221e-05,
#    3.217608041268249e-05,
#    3.333560789542389e-05,
#    3.242675784349558e-05,
#    2.916309922511573e-05,
#    3.2189157718676145e-05,
#    3.245587272431294e-05,
#    3.121165595985076e-05,
#    3.085881048718875e-05,
#    2.672478976819548e-05,
#    2.693156397981511e-05,
#    2.7611923223958e-05,
#    2.5586686933820602e-05,
#    2.614851459838974e-05,
#    2.7091314950666857e-05,
#    2.7536078505363548e-05,
#    2.530569804548577e-05,
#    2.563308212302218e-05,
#    2.350633435526106e-05,
#    2.470089898451988e-05,
#    2.4211906838900178e-05,
#    2.5793949907892967e-05,
#    2.3586008774145738e-05,
#    2.2504354046759544e-05,
#    2.3224454662340576e-05,
#    2.304460626874061e-05,
#    2.2662867559120058e-05],
#   'pred_loss_va': [0.011653791787102819,
#    0.009313486819155514,
#    0.008242776151746511,
#    0.007237634959165007,
#    0.006362212495878339,
#    0.005882384697906673,
#    0.005185332684777677,
#    0.004895901365671307,
#    0.0052686581097077575,
#    0.00444151348201558,
#    0.005093945388216526,
#    0.004696792917093262,
#    0.004038050031522289,
#    0.0036602404492441566,
#    0.0039141079701948914,
#    0.004626865062164143,
#    0.0037720587803050875,
#    0.0029484789760317654,
#    0.003538836777443066,
#    0.0027928734023589643,
#    0.003192613134160638,
#    0.002599093402386643,
#    0.0038767771271523087,
#    0.0033538123359903695,
#    0.0021582373272394763,
#    0.0034776968881487847,
#    0.0024676678905962033,
#    0.002867387648439035,
#    0.002295538326143287,
#    0.002558895471156575,
#    0.002409761256421916,
#    0.003192135883728042,
#    0.0017374459886923433,
#    0.0020441717671928926,
#    0.0023112185532227158,
#    0.0018158646271331236,
#    0.0020778363454155625,
#    0.0018066805903799831,
#    0.0028322192607447504,
#    0.0020741398766404018,
#    0.0020731346274260433,
#    0.001966711669228971,
#    0.002167809393722564,
#    0.0021605092246318237,
#    0.0034807309682946654,
#    0.0020552202651742844,
#    0.0016252311412245034,
#    0.001901012979215011,
#    0.001780108848470263,
#    0.0020603072160156445],
#   'total_loss_va': [0.001268006706959568,
#    0.0009898125179461203,
#    0.0008852475992171093,
#    0.0007749057680484839,
#    0.0006859169545350597,
#    0.0006596032573725097,
#    0.000576500766328536,
#    0.0005390161102695856,
#    0.0005939577335084323,
#    0.0004908193630399182,
#    0.0005676395689079072,
#    0.0005226459419645834,
#    0.0004600659798597917,
#    0.0004256457934388891,
#    0.000444664983660914,
#    0.0005231533628830221,
#    0.00043095149085274896,
#    0.00034242712863488125,
#    0.00041161729168379677,
#    0.00032764515563030725,
#    0.00036671880952781065,
#    0.0003105700892774621,
#    0.0004349575363448821,
#    0.00038444992314907723,
#    0.0002606914953503292,
#    0.0004043451452162117,
#    0.0002896657922974555,
#    0.0003520420039421879,
#    0.00027097547899757046,
#    0.00029538486887759063,
#    0.0002834511484252289,
#    0.0003595171237975592,
#    0.00020808195477002301,
#    0.00023847277734603267,
#    0.0002691976511414396,
#    0.0002137015875632642,
#    0.00024382712108490524,
#    0.00021791090839542448,
#    0.0003209470072761178,
#    0.0002433463952911552,
#    0.00024158777450793422,
#    0.00023125813895603643,
#    0.0002495169290341437,
#    0.00024846648557286244,
#    0.00038427004183176904,
#    0.0002432718909403775,
#    0.00019324965760461054,
#    0.00022611392305407207,
#    0.00020942645314789843,
#    0.00023736438088235446]})

# %%
trainer.test_KoopmanAE(test_loader)
# Out:
# Test - Recon Loss: 8.854600e-05, Linear Loss: 2.268356e-05, Pred Loss: 2.027326e-03, Total Loss: 2.342708e-04

# %% [markdown]
# ## Visualization
#
# Visualize the original, reconstructed, and predicted trajectories from the test set.

# %%
# for saving the results first

# Get a test sample
traj = preprocessed_data["Xtest"][0].to(device)

# Get reconstructed trajectory
model.eval()
with torch.no_grad():
    Y, reconstructed_traj = model.ae(traj)


# Get predicted trajectory
predicted_traj, latent_pred = trainer.predict_new(X0=traj[0], steps=len(traj)-1)

# Convert to numpy for plotting
traj = traj.cpu().detach().numpy()
reconstructed_traj = reconstructed_traj.cpu().detach().numpy()
predicted_traj = predicted_traj.cpu().detach().numpy()

# Plot trajectories
plot_trajectories(traj[:,:3], predicted_traj[:,:3], reconstructed_traj[:,:3], folder_path=folder_path,save=True)
plot_trajectory_comparison(traj, predicted_traj, reconstructed_traj, folder_path=folder_path,save=True)

# %%
# for saving the results first

# Get a test sample
traj = preprocessed_data["Xtest"][0].to(device)

# Get reconstructed trajectory
model.eval()
with torch.no_grad():
    Y, reconstructed_traj = model.ae(traj)


# Get predicted trajectory
predicted_traj, latent_pred = trainer.predict_new(X0=traj[0], steps=len(traj)-1)

# Convert to numpy for plotting
traj = traj.cpu().detach().numpy()
reconstructed_traj = reconstructed_traj.cpu().detach().numpy()
predicted_traj = predicted_traj.cpu().detach().numpy()

# Plot trajectories
plot_trajectories(traj[:,:3], predicted_traj[:,:3], reconstructed_traj[:,:3], folder_path=folder_path,save=False)
plot_trajectory_comparison(traj, predicted_traj, reconstructed_traj, folder_path=folder_path,save=False)

# %% [markdown]
# ## Reencoding

# %% [markdown]
# ### Periodic Reencoding

# %%
# for saving the results first

# Get a test sample
traj = preprocessed_data["Xtest"][0].to(device)

# Get reconstructed trajectory
model.eval()
with torch.no_grad():
    Y, reconstructed_traj = model.ae(traj)


# Get predicted trajectory
predicted_traj, latent_pred = trainer.predict_new_Periodic_Reencoding(X0=traj[0], steps=len(traj)-1,reenc=15)

# Convert to numpy for plotting
traj = traj.cpu().detach().numpy()
reconstructed_traj = reconstructed_traj.cpu().detach().numpy()
predicted_traj = predicted_traj.cpu().detach().numpy()

# Plot trajectories
plot_trajectories(traj[:,:3], predicted_traj[:,:3], reconstructed_traj[:,:3], folder_path=folder_path,save=False)
plot_trajectory_comparison(traj, predicted_traj, reconstructed_traj, folder_path=folder_path,save=False)

# %% [markdown]
# ### Window Approach

# %%
# for saving the results first

# Get a test sample
traj = preprocessed_data["Xtest"][0].to(device)

# Get reconstructed trajectory
model.eval()
with torch.no_grad():
    Y, reconstructed_traj = model.ae(traj)


# Get predicted trajectory
predicted_traj, latent_pred, reencoding_points, _ = trainer.predict_window_variance(X0=traj[0], steps=len(traj)-1, window_size=10, variance_threshold=2)

print(f"Reencoding points: {reencoding_points}")
# Convert to numpy for plotting
traj = traj.cpu().detach().numpy()
reconstructed_traj = reconstructed_traj.cpu().detach().numpy()
predicted_traj = predicted_traj.cpu().detach().numpy()

# Plot trajectories
plot_trajectories(traj[:,:3], predicted_traj[:,:3], reconstructed_traj[:,:3], folder_path=folder_path,save=False)
plot_trajectory_comparison(traj, predicted_traj, reconstructed_traj, folder_path=folder_path,save=False)
# Out:
# Reencoding points: [14, 18, 46, 78, 106, 130, 161, 189, 221, 251, 272, 302, 333, 361, 386, 417, 439, 465, 486, 519, 536, 542, 551, 582, 596, 636, 662, 708, 732, 754, 766, 778, 804, 828, 846, 867, 911, 932, 953, 981]

# %% [markdown]
# ### Threshold Approach

# %%
# for saving the results first

# Get a test sample
traj = preprocessed_data["Xtest"][0].to(device)

# Get reconstructed trajectory
model.eval()
with torch.no_grad():
    Y, reconstructed_traj = model.ae(traj)


# Get predicted trajectory
predicted_traj, latent_pred, reencoding_points = trainer.predict_with_threshold(X0=traj[0], steps=len(traj)-1, threshold=1)

print(f"Reencoding points: {reencoding_points}")
# Convert to numpy for plotting
traj = traj.cpu().detach().numpy()
reconstructed_traj = reconstructed_traj.cpu().detach().numpy()
predicted_traj = predicted_traj.cpu().detach().numpy()

# Plot trajectories
plot_trajectories(traj[:,:3], predicted_traj[:,:3], reconstructed_traj[:,:3], folder_path=folder_path,save=False)
plot_trajectory_comparison(traj, predicted_traj, reconstructed_traj, folder_path=folder_path,save=False)
# Out:
# Reencoding points: [5, 55, 84, 102, 131, 136, 140, 158, 163, 173, 179, 185, 186, 198, 202, 209, 214, 220, 228, 242, 253, 259, 264, 271, 319, 338, 383, 438, 486, 534, 583, 632, 683, 712, 737, 758, 782, 806, 829, 852, 875, 898, 921, 945, 968, 991]

# %% [markdown]
# ## Long Term Prediction

# %%
from utils.data_loader import GoodwinOscillator

Y0 = np.random.uniform(-2, 2, 3)

goodwin_model = GoodwinOscillator(y0=Y0)

parameters = [360, 43, 1.0, 12, 0.6, 1.0, 1.0, 1.0, 0.8]

times = np.linspace(0, 100, 501)

traj = goodwin_model.simulate(parameters, times)

traj = traj/data_handler.Xscale

# %%
# visualize the trajectory

plt.figure(figsize=(10, 6))
plt.plot(times, traj[:, 0], label='X1', color='blue')
plt.plot(times, traj[:, 1], label='X2', color='orange')
plt.plot(times, traj[:, 2], label='X3', color='green')
plt.title('Goodwin Oscillator Trajectory')
plt.xlabel('Time')
plt.ylabel('State Variables')
plt.legend()
plt.grid()

# %%
# traj as tensor
traj = torch.tensor(traj, dtype=torch.float32).to(device)

# Get reconstructed trajectory
model.eval()
with torch.no_grad():
    Y, reconstructed_traj = model.ae(traj)


# Get predicted trajectory
predicted_traj, latent_traj = trainer.predict_new(X0=traj[0], steps=len(traj)-1)

# Convert to numpy for plotting
traj = traj.cpu().detach().numpy()
reconstructed_traj = reconstructed_traj.cpu().detach().numpy()
predicted_traj = predicted_traj.cpu().detach().numpy()

# Plot trajectories
plot_trajectories(traj[:,:3], predicted_traj[:,:3], reconstructed_traj[:,:3], folder_path=folder_path,save=False)
plot_trajectory_comparison(traj, predicted_traj, reconstructed_traj, folder_path=folder_path,save=False)

# %% [markdown]
# ## Testing on Test Loader

# %%
# print length of test_loader
print(f" the length of the test_loader is {len(test_loader.dataset)}")
# Out:
#  the length of the test_loader is 5000

# %%
print(test_loader.dataset[0][0].shape)
# Out:
# torch.Size([41, 3])

# %%
# Get a test sample
traj = train_loader.dataset[71][0].to(device)

# Get reconstructed trajectory
model.eval()
with torch.no_grad():
    Y, reconstructed_traj = model.ae(traj)


# Get predicted trajectory
predicted_traj, latent_pred = trainer.predict_new(X0=traj[0], steps=len(traj)-1)

# Convert to numpy for plotting
traj = traj.cpu().detach().numpy()
reconstructed_traj = reconstructed_traj.cpu().detach().numpy()
predicted_traj = predicted_traj.cpu().detach().numpy()

# Plot trajectories
plot_trajectories(traj[:,:3], predicted_traj[:,:3], reconstructed_traj[:,:3], folder_path=folder_path,save=False)
plot_trajectory_comparison(traj, predicted_traj, reconstructed_traj, folder_path=folder_path,save=False)

# %% [markdown]
# ## Eigenvalues Visualization
#
# Compute and visualize the eigenvalues of the Koopman operator on a unit circle.

# %%
# Compute eigenvalues
eigenvalues, eigenvectors = torch.linalg.eig(model.knet.net.weight)
eigenvalues = eigenvalues.cpu().detach().numpy()
idx = np.argsort(eigenvalues.real)[::-1]
eigenvalues = eigenvalues[idx]

# Print eigenvalues
print('Eigenvalues:')
print(eigenvalues)

# Plot eigenvalues on unit circle
plot_eigenvalues_on_unit_circle(eigenvalues, folder_path)

print(f"Training and evaluation completed. Results saved in {folder_path}")
# Out:
# Eigenvalues:
# [ 1.0001057 +0.j          0.9970453 +0.07680552j  0.9970453 -0.07680552j
#   0.9871526 -0.15999956j  0.9871526 +0.15999956j  0.97533774-0.22171801j
#   0.97533774+0.22171801j  0.9713103 -0.23833446j  0.9713103 +0.23833446j
#   0.96617806-0.25847355j  0.96617806+0.25847355j  0.9400836 -0.34099734j
#   0.9400836 +0.34099734j  0.9164328 +0.40012318j  0.9164328 -0.40012318j
#   0.8767828 +0.48105553j  0.8767828 -0.48105553j  0.83270264+0.55369866j
#   0.83270264-0.55369866j  0.8069086 +0.59066653j  0.8069086 -0.59066653j
#   0.76363623+0.6456434j   0.76363623-0.6456434j   0.7080153 -0.70617723j
#   0.7080153 +0.70617723j  0.6803459 +0.7328775j   0.6803459 -0.7328775j
#   0.6274339 -0.7786766j   0.6274339 +0.7786766j   0.61131823-0.7913915j
#   0.61131823+0.7913915j   0.56126875+0.8276262j   0.56126875-0.8276262j
#   0.5269358 -0.8499103j   0.5269358 +0.8499103j   0.4497937 -0.8931303j
#   0.4497937 +0.8931303j   0.40399602+0.9147495j   0.40399602-0.9147495j
#   0.34467885-0.9387134j   0.34467885+0.9387134j   0.303954  -0.9526969j
#   0.303954  +0.9526969j   0.21310225+0.97702914j  0.21310225-0.97702914j
#   0.15956861-0.9871771j   0.15956861+0.9871771j   0.10483211-0.99448234j
#   0.10483211+0.99448234j  0.03075781+0.9995278j   0.03075781-0.9995278j
#   0.0031162 -0.9999946j   0.0031162 +0.9999946j  -0.04319184-0.9990681j
#  -0.04319184+0.9990681j  -0.1354892 -0.9907762j  -0.1354892 +0.9907762j
#  -0.18112084+0.9834559j  -0.18112084-0.9834559j  -0.26812205-0.9633791j
#  -0.26812205+0.9633791j  -0.32619154-0.9452967j  -0.32619154+0.9452967j
#  -0.3561731 -0.9344131j  -0.3561731 +0.9344131j  -0.44782043-0.8941018j
#  -0.44782043+0.8941018j  -0.49655068+0.8679881j  -0.49655068-0.8679881j
#  -0.597857  +0.80159205j -0.597857  -0.80159205j -0.6508155 +0.75922674j
#  -0.6508155 -0.75922674j -0.6726184 +0.73998934j -0.6726184 -0.73998934j
#  -0.71096313-0.7032461j  -0.71096313+0.7032461j  -0.7748145 -0.6321974j
#  -0.7748145 +0.6321974j  -0.80397934+0.594648j   -0.80397934-0.594648j
#  -0.8537172 +0.5207333j  -0.8537172 -0.5207333j  -0.8738773 +0.48614925j
#  -0.8738773 -0.48614925j -0.9013765 -0.43305737j -0.9013765 +0.43305737j
#  -0.93413275-0.35689545j -0.93413275+0.35689545j -0.9644164 -0.26433587j
#  -0.9644164 +0.26433587j -0.9700884 -0.24270691j -0.9700884 +0.24270691j
#  -0.9829972 +0.18359913j -0.9829972 -0.18359913j -0.9909632 -0.13415092j
#  -0.9909632 +0.13415092j -0.9982065 -0.05960519j -0.9982065 +0.05960519j
#  -1.000004  +0.j        ]
# Training and evaluation completed. Results saved in experiments/goodwin_oscillator_AFT_Dynamic_Reencoding

# %%
# print the knet weights
weights = model.knet.net.weight.cpu().detach().numpy() 
# Visualize the weight matrix using matplotlib
plt.imshow(weights, cmap='viridis', aspect='auto')
plt.colorbar()
plt.title("Weight Matrix of the Linear Layer")
plt.xlabel("Input Features")
plt.ylabel("Output Features")
plt.show()

# %%
# print the entire koopman operator in full 
print(f" the koopman operator is {model.knet.net.weight[0]}")
# Out:
#  the koopman operator is tensor([-1.8938e-01, -1.0406e-01, -8.5512e-02,  4.3712e-02,  1.4280e-01,
#         -1.4764e-01, -1.7441e-02, -6.2565e-02,  3.2523e-02, -2.0874e-01,
#         -5.4121e-02, -1.0126e-01, -7.4361e-02, -1.0856e-01,  6.2703e-02,
#          2.0849e-02, -1.2878e-01,  1.5091e-01, -1.4927e-01,  6.9021e-02,
#         -9.7095e-02, -1.8007e-02, -3.2278e-02,  1.4288e-01, -5.9094e-02,
#          9.7659e-02, -1.2841e-01,  1.4382e-01, -1.1917e-01,  3.7599e-02,
#         -1.6378e-01,  2.0059e-02, -8.5884e-02, -1.4257e-01,  5.9698e-02,
#          7.3033e-02, -1.3272e-01,  1.2752e-01,  5.7485e-03,  5.4934e-02,
#          1.1430e-01,  1.3575e-01, -4.7970e-03, -1.9808e-04,  1.9373e-02,
#         -2.2466e-02, -1.9144e-01, -1.0648e-01, -1.5040e-02, -3.1012e-02,
#         -9.8635e-02, -1.4910e-01, -1.0150e-01,  5.1819e-02,  7.9281e-02,
#         -4.0161e-03, -3.6739e-02, -1.1994e-02,  5.6917e-02,  1.0252e-01,
#          1.6022e-01,  1.1004e-01,  1.8330e-01, -4.8530e-02,  5.0200e-02,
#          1.0458e-01,  1.6018e-02,  5.9578e-02,  7.3891e-03, -1.0102e-01,
#         -7.4408e-02, -7.3526e-02,  2.2575e-02,  1.2473e-01,  1.8881e-01,
#          1.2493e-01, -3.0664e-02, -6.3982e-02, -1.1219e-01, -1.8409e-03,
#         -1.0756e-01,  1.6998e-02,  1.3502e-01, -9.6182e-02, -2.9259e-02,
#          5.0282e-02,  1.0198e-01, -1.1218e-01, -3.6568e-02,  6.2128e-03,
#         -5.9250e-02,  1.7929e-01,  5.9396e-02,  7.5853e-02,  1.2415e-01,
#         -1.6800e-01, -1.2427e-01,  1.8195e-01, -2.0904e-03,  6.7453e-02],
#        grad_fn=<SelectBackward0>)

# %%
violin_plot(model, preprocessed_data["Xtest"], device, folder_path)
