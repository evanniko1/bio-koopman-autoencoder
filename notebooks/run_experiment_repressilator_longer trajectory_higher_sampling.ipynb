# %% [markdown]
# # Koopman Operator Training with Autoencoder
#
# This notebook implements a training pipeline for a Koopman operator model combined with an autoencoder. The code includes data loading, model definition, training, and visualization of results such as trajectories and eigenvalues.

# %%
import os
# Move up one directory to make sure the script can find the modules and save files in the correct place
os.chdir('..')
# Verify the current working directory
print(os.getcwd())

import argparse
import json
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, Dataset
import torch.nn.init as init
import torch.multiprocessing as mp

# Import local modules (assuming these are available in your environment)
from utils.tools import set_seed, get_device
from utils.config_args import get_args
from utils.Viz import *
from KoopmanTrainer import Trainer
from data_handler import KoopmanDataHandler
from models.autoencoder import AutoEncoder
from models.koopman_operator import Knet

# Set multiprocessing start method
try:
    mp.set_start_method('spawn')
except RuntimeError:
    pass  # method already set

# Disable deterministic algorithms for flexibility
torch.use_deterministic_algorithms(False)
# Out:
# /Users/mohammedahmed/Desktop/Project/KoopKAN/Testing Multiple Repos/bio-koopman-autoencoder

# %% [markdown]
# ## Training Settings
#
# Configure the training settings, including random seeds for reproducibility and device selection (CUDA or CPU).

# %%
# Get arguments (assuming get_args() handles command-line or default args)
args = get_args()

# Set seeds for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.cuda.manual_seed(args.seed)
torch.manual_seed(args.seed)
np.random.seed(args.seed)
set_seed(args.seed)

# Device configuration
device = get_device()
# Out:
# Using the CPU

# %%
# editing the args 
# in this experiement we increased the timesteps to 201 and the time to 40 which is double the original experiment to make sure we would capture the limit cycle 
args.dataset = 'isolated_repressilator'
args.folder = 'isolated_repressilator_200_time_steps_64_bottleneck_higher_sampling'
args.time_steps = 201
args.prediction_length = 200
args.max_time = 20
args.num_samples = 15000
args.bottleneck = 64
args.decoder_loss_weight = 10
args.lr = 1e-3
args.epochs = 300
args.loss_function = 'mse'
args.unitary_loss_weight = 10

# %% [markdown]
# ## Create Experiment Folder
#
# Set up the folder structure to save experiment results, including arguments in a JSON file.

# %%
# Create experiment folder
experiment_folder = 'experiments'
if not os.path.isdir(experiment_folder):
    os.mkdir(experiment_folder)

folder_path = os.path.join(experiment_folder, args.folder)
os.makedirs(folder_path, exist_ok=True)

# Save arguments to JSON
args_dict = vars(args)
with open(os.path.join(folder_path, 'args.json'), 'w') as f:
    json.dump(args_dict, f,indent=2)

# %% [markdown]
# ## Load and Prepare Dataset
#
# Load and preprocess the dataset using the `KoopmanDataHandler` class, then create data loaders for training, validation, and testing.

# %%
# Convert args to a dictionary for the data handler

config = {
    "dataset": args.dataset,
    "data_dir": args.data_dir,
    "train_size": args.train_size,
    "val_size": args.val_size,
    "batch_size": args.batch_size,
    "noise": args.noise,
    "orthogonal_projection": args.orthogonal_projection,
    "num_combinations": args.num_combinations,
    "num_samples": args.num_samples,
    "time_steps": args.time_steps,
    "max_time": args.max_time,
    "normalize": args.normalize,
    "prediction_length": args.prediction_length,
    "stride": args.stride,
    "device": device,
    "theta": args.theta
}

# Initialize data handler
data_handler = KoopmanDataHandler(config)
data_handler.load_data()
preprocessed_data = data_handler.preprocess()
dataloaders = data_handler.create_dataloaders()

train_loader = dataloaders["train"]
val_loader = dataloaders["val"]
test_loader = dataloaders["test"]

# Get data dimensions for model initialization
input_size = preprocessed_data['Xtrain'].shape[-1]
# Out:
# Generating data...
# 100%|██████████| 15000/15000 [00:00<00:00, 42967.76it/s]
# /Users/mohammedahmed/Desktop/Project/KoopKAN/Testing Multiple Repos/bio-koopman-autoencoder/data_handler.py:130: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Xtrain = torch.tensor(Xtrain, dtype=torch.float32).to(self.device)
# /Users/mohammedahmed/Desktop/Project/KoopKAN/Testing Multiple Repos/bio-koopman-autoencoder/data_handler.py:131: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Xval = torch.tensor(Xval, dtype=torch.float32).to(self.device)
# /Users/mohammedahmed/Desktop/Project/KoopKAN/Testing Multiple Repos/bio-koopman-autoencoder/data_handler.py:132: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Xtest = torch.tensor(Xtest, dtype=torch.float32).to(self.device)
# the shape of the data is torch.Size([15000, 201, 6])
# Processing dataset: isolated_repressilator
# train_idx: 12000, val_idx: 13500
# Processed data shapes - Train: torch.Size([12000, 201, 6]), Val: torch.Size([1500, 201, 6]), Test: torch.Size([1500, 201, 6])

# %% [markdown]
# ## Model Definition
#
# Define the autoencoder (`AutoEncoder`) and Koopman operator (`Knet`), then combine them into a `ModuleDict`.

# %%
# Model definition
ae = AutoEncoder(
    input_size=input_size,
    encoded_size=args.bottleneck,
    encoder_hidden_layers=args.encoder_hidden_layers,
    decoder_hidden_layers=args.decoder_hidden_layers,
    network_type=args.network_type,
    batch_norm=False
)
knet = Knet(size=args.bottleneck)

# Combine AE and Knet as a ModuleDict
model = torch.nn.ModuleDict({'ae': ae, 'knet': knet})
model = model.to(device)

# %% [markdown]
# ## Model Summary
#
# Display the total number of parameters and the model architecture.

# %%
print('**** Setup ****')
print('Total params: %.2fM' % (sum(p.numel() for p in model.parameters())/1000000.0))
print('Total params: %.2fk' % (sum(p.numel() for p in model.parameters())/1000.0))
print('************')

print('**** Model Architecture ****')
print(model)
print('***************************')
# Out:
# **** Setup ****
# Total params: 0.04M
# Total params: 38.57k
# ************
# **** Model Architecture ****
# ModuleDict(
#   (ae): AutoEncoder(
#     (encoder): Sequential(
#       (0): MLP(
#         (net): ModuleList(
#           (0): Linear(in_features=6, out_features=100, bias=True)
#           (1): LeakyReLU(negative_slope=0.01)
#           (2): Linear(in_features=100, out_features=100, bias=True)
#           (3): LeakyReLU(negative_slope=0.01)
#           (4): Linear(in_features=100, out_features=64, bias=True)
#         )
#       )
#       (1): Dropout(p=0.3, inplace=False)
#     )
#     (decoder): MLP(
#       (net): ModuleList(
#         (0): Linear(in_features=64, out_features=100, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): Linear(in_features=100, out_features=100, bias=True)
#         (3): LeakyReLU(negative_slope=0.01)
#         (4): Linear(in_features=100, out_features=6, bias=True)
#       )
#     )
#   )
#   (knet): Knet(
#     (net): Linear(in_features=64, out_features=64, bias=False)
#   )
# )
# ***************************

# %% [markdown]
# ## Load from Checkpoint
#
# Optionally load a pre-trained model from a checkpoint if specified.

# %%
if args.load_from_checkpoint:
    checkpoint_path = os.path.join(folder_path, 'model.pkl')
    if os.path.isfile(checkpoint_path):
        model.load_state_dict(torch.load(checkpoint_path))
        print(f'Model loaded from {checkpoint_path}')
    else:
        print(f'No checkpoint found at {checkpoint_path}')

# %% [markdown]
# ## Training
#
# Train the model using the `Trainer` class with the specified data loaders.

# %%
trainer = Trainer(model, args, device, do_eval=True, train_loader=train_loader, val_loader=val_loader)
# Out:
# Using the CPU

# %%
trainer.train_KoopmanAE()
# Out:
# Training Epochs:   7%|▋         | 20/300 [05:44<1:24:04, 18.02s/it]
# Epoch 20/300
# Training - Recon Loss: 9.000285e-05, Linear Loss: 3.013764e-04, Pred Loss: 5.818406e-04, Unitary Loss: 4.759181e-05, Total Loss: 7.495729e-03
# Validation - Recon Loss: 4.051633e-05, Linear Loss: 2.230148e-04, Pred Loss: 4.492012e-04,Unitary Loss: 4.626414e-05, Total Loss: 5.120190e-03
# Training Epochs:  13%|█▎        | 40/300 [11:39<1:15:34, 17.44s/it]
# Epoch 40/300
# Training - Recon Loss: 8.156100e-05, Linear Loss: 2.444885e-04, Pred Loss: 3.811561e-04, Unitary Loss: 3.781420e-05, Total Loss: 5.249801e-03
# Validation - Recon Loss: 4.276531e-05, Linear Loss: 1.474388e-04, Pred Loss: 2.437848e-04,Unitary Loss: 4.116284e-05, Total Loss: 3.012940e-03
# Training Epochs:  20%|██        | 60/300 [17:02<58:56, 14.74s/it]
# Epoch 60/300
# Training - Recon Loss: 6.377267e-05, Linear Loss: 2.265175e-04, Pred Loss: 2.792620e-04, Unitary Loss: 2.991073e-05, Total Loss: 3.955972e-03
# Validation - Recon Loss: 3.758189e-05, Linear Loss: 1.318891e-04, Pred Loss: 1.771874e-04,Unitary Loss: 2.977824e-05, Total Loss: 2.279582e-03
# Training Epochs:  27%|██▋       | 80/300 [21:22<47:48, 13.04s/it]
# Epoch 80/300
# Training - Recon Loss: 7.864439e-05, Linear Loss: 2.061821e-04, Pred Loss: 2.918683e-04, Unitary Loss: 2.908330e-05, Total Loss: 4.202142e-03
# Validation - Recon Loss: 5.095046e-05, Linear Loss: 1.354330e-04, Pred Loss: 2.360071e-04,Unitary Loss: 3.023059e-05, Total Loss: 3.005008e-03
# Training Epochs:  33%|███▎      | 100/300 [26:17<42:38, 12.79s/it]
# Epoch 100/300
# Training - Recon Loss: 5.058595e-05, Linear Loss: 1.568547e-04, Pred Loss: 2.445574e-04, Unitary Loss: 2.313131e-05, Total Loss: 3.339602e-03
# Validation - Recon Loss: 2.707771e-05, Linear Loss: 9.297709e-05, Pred Loss: 1.657567e-04,Unitary Loss: 2.262414e-05, Total Loss: 2.021322e-03
# Training Epochs:  40%|████      | 120/300 [31:51<55:30, 18.50s/it]
# Epoch 120/300
# Training - Recon Loss: 4.856221e-05, Linear Loss: 1.532377e-04, Pred Loss: 2.374500e-04, Unitary Loss: 2.230112e-05, Total Loss: 3.236371e-03
# Validation - Recon Loss: 2.406996e-05, Linear Loss: 8.334791e-05, Pred Loss: 1.731748e-04,Unitary Loss: 2.190344e-05, Total Loss: 2.055795e-03
# Training Epochs:  47%|████▋     | 140/300 [38:10<51:06, 19.16s/it]
# Epoch 140/300
# Training - Recon Loss: 4.862143e-05, Linear Loss: 1.396716e-04, Pred Loss: 1.607520e-04, Unitary Loss: 2.166972e-05, Total Loss: 2.450103e-03
# Validation - Recon Loss: 3.015406e-05, Linear Loss: 7.720563e-05, Pred Loss: 1.799211e-04,Unitary Loss: 2.059109e-05, Total Loss: 2.177957e-03
# Training Epochs:  53%|█████▎    | 160/300 [52:26<33:21, 14.30s/it]
# Epoch 160/300
# Training - Recon Loss: 4.514861e-05, Linear Loss: 1.327292e-04, Pred Loss: 1.508088e-04, Unitary Loss: 2.076462e-05, Total Loss: 2.299949e-03
# Validation - Recon Loss: 2.445666e-05, Linear Loss: 7.504052e-05, Pred Loss: 1.352574e-04,Unitary Loss: 1.983489e-05, Total Loss: 1.672181e-03
# Training Epochs:  60%|██████    | 180/300 [56:50<25:21, 12.68s/it]
# Epoch 180/300
# Training - Recon Loss: 4.145887e-05, Linear Loss: 1.227090e-04, Pred Loss: 1.789320e-04, Unitary Loss: 1.926869e-05, Total Loss: 2.519304e-03
# Validation - Recon Loss: 2.093895e-05, Linear Loss: 7.108278e-05, Pred Loss: 1.872709e-04,Unitary Loss: 1.967856e-05, Total Loss: 2.153182e-03
# Training Epochs:  67%|██████▋   | 200/300 [1:01:03<21:17, 12.78s/it]
# Epoch 200/300
# Training - Recon Loss: 4.069055e-05, Linear Loss: 1.163055e-04, Pred Loss: 1.280711e-04, Unitary Loss: 1.849776e-05, Total Loss: 1.988900e-03
# Validation - Recon Loss: 2.274587e-05, Linear Loss: 6.823619e-05, Pred Loss: 8.871628e-05,Unitary Loss: 1.857510e-05, Total Loss: 1.182858e-03
# Training Epochs:  73%|███████▎  | 220/300 [1:05:17<16:48, 12.61s/it]
# Epoch 220/300
# Training - Recon Loss: 4.186066e-05, Linear Loss: 1.125662e-04, Pred Loss: 1.346104e-04, Unitary Loss: 1.856102e-05, Total Loss: 2.062887e-03
# Validation - Recon Loss: 1.938715e-05, Linear Loss: 7.070576e-05, Pred Loss: 6.972079e-05,Unitary Loss: 1.835445e-05, Total Loss: 9.617852e-04
# Training Epochs:  80%|████████  | 240/300 [1:11:23<17:42, 17.71s/it]
# Epoch 240/300
# Training - Recon Loss: 3.788720e-05, Linear Loss: 1.069421e-04, Pred Loss: 1.450939e-04, Unitary Loss: 1.784664e-05, Total Loss: 2.115219e-03
# Validation - Recon Loss: 1.841261e-05, Linear Loss: 6.552325e-05, Pred Loss: 6.833187e-05,Unitary Loss: 1.757035e-05, Total Loss: 9.329680e-04
# Training Epochs:  87%|████████▋ | 260/300 [1:17:31<12:23, 18.59s/it]
# Epoch 260/300
# Training - Recon Loss: 3.764670e-05, Linear Loss: 1.024970e-04, Pred Loss: 1.180147e-04, Unitary Loss: 1.746931e-05, Total Loss: 1.833804e-03
# Validation - Recon Loss: 1.956425e-05, Linear Loss: 6.390488e-05, Pred Loss: 7.672480e-05,Unitary Loss: 1.780881e-05, Total Loss: 1.026795e-03
# Training Epochs:  93%|█████████▎| 280/300 [1:23:36<05:56, 17.84s/it]
# Epoch 280/300
# Training - Recon Loss: 3.582261e-05, Linear Loss: 1.002023e-04, Pred Loss: 1.282277e-04, Unitary Loss: 1.672470e-05, Total Loss: 1.907952e-03
# Validation - Recon Loss: 1.839136e-05, Linear Loss: 6.357525e-05, Pred Loss: 6.969175e-05,Unitary Loss: 1.683012e-05, Total Loss: 9.444063e-04
# Training Epochs: 100%|██████████| 300/300 [1:29:50<00:00, 17.97s/it]
# Epoch 300/300
# Training - Recon Loss: 3.590386e-05, Linear Loss: 9.752183e-05, Pred Loss: 1.341400e-04, Unitary Loss: 1.716680e-05, Total Loss: 1.969628e-03
# Validation - Recon Loss: 1.747808e-05, Linear Loss: 5.737811e-05, Pred Loss: 9.205611e-05,Unitary Loss: 1.565957e-05, Total Loss: 1.152720e-03
# (ModuleDict(
#    (ae): AutoEncoder(
#      (encoder): Sequential(
#        (0): MLP(
#          (net): ModuleList(
#            (0): Linear(in_features=6, out_features=100, bias=True)
#            (1): LeakyReLU(negative_slope=0.01)
#            (2): Linear(in_features=100, out_features=100, bias=True)
#            (3): LeakyReLU(negative_slope=0.01)
#            (4): Linear(in_features=100, out_features=64, bias=True)
#          )
#        )
#        (1): Dropout(p=0.3, inplace=False)
#      )
#      (decoder): MLP(
#        (net): ModuleList(
#          (0): Linear(in_features=64, out_features=100, bias=True)
#          (1): LeakyReLU(negative_slope=0.01)
#          (2): Linear(in_features=100, out_features=100, bias=True)
#          (3): LeakyReLU(negative_slope=0.01)
#          (4): Linear(in_features=100, out_features=6, bias=True)
#        )
#      )
#    )
#    (knet): Knet(
#      (net): Linear(in_features=64, out_features=64, bias=False)
#    )
#  ),
#  AdamW (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      capturable: False
#      differentiable: False
#      eps: 1e-08
#      foreach: None
#      fused: None
#      lr: 0.0004096000000000001
#      maximize: False
#      weight_decay: 0.0
#  ),
#  {'recon_loss_tr': [0.0009870271550174406,
#    9.238722362924625e-05,
#    9.77978586192005e-05,
#    0.0001090089997965248,
#    9.041636664559074e-05,
#    9.847478244448715e-05,
#    9.949499508365989e-05,
#    0.00010700417415330563,
#    8.714599305753932e-05,
#    8.97645356630203e-05,
#    0.0001367191417809041,
#    0.00010105362169734361,
#    8.161306640373523e-05,
#    0.00012576467572139238,
#    8.667437624411677e-05,
#    8.139215486230665e-05,
#    8.572456724149116e-05,
#    8.114130585144789e-05,
#    0.00010510698368616819,
#    9.000285338496473e-05,
#    8.243437820210795e-05,
#    7.93896501721626e-05,
#    7.658099228989313e-05,
#    0.00010515161216546326,
#    9.015051878993696e-05,
#    7.93124729286919e-05,
#    0.00010812163964146748,
#    8.864750603568106e-05,
#    0.00011241102440683963,
#    7.230464580835417e-05,
#    8.882646541175572e-05,
#    8.800458361176735e-05,
#    7.835728854146548e-05,
#    6.924935320405875e-05,
#    7.125728463622781e-05,
#    7.501333149117814e-05,
#    8.315664115101793e-05,
#    6.944556662347168e-05,
#    7.303547569423012e-05,
#    8.156100499191064e-05,
#    7.446897100809555e-05,
#    7.97687387100094e-05,
#    7.683160924414629e-05,
#    6.650443522611316e-05,
#    7.064404390087263e-05,
#    7.238800927997873e-05,
#    7.715650288910764e-05,
#    9.213762252252213e-05,
#    6.725805004417124e-05,
#    6.386518795439537e-05,
#    6.352966328391786e-05,
#    6.728256096508592e-05,
#    6.60653595138896e-05,
#    7.732012381119545e-05,
#    9.286893320212913e-05,
#    6.739121005360157e-05,
#    6.544126150169797e-05,
#    8.356877739796356e-05,
#    8.460719463789459e-05,
#    6.377267105717886e-05,
#    6.571906495547081e-05,
#    6.677164527261877e-05,
#    6.193620898324917e-05,
#    7.21423378095967e-05,
#    6.042572765201182e-05,
#    7.106850085968271e-05,
#    6.105356945401117e-05,
#    8.175395162246051e-05,
#    6.554175660254414e-05,
#    6.75168603846303e-05,
#    5.690414500930545e-05,
#    5.913248981201793e-05,
#    5.97037045387898e-05,
#    5.8790049189020524e-05,
#    5.768079941806215e-05,
#    6.031558691478146e-05,
#    6.917280502130645e-05,
#    6.28787508135924e-05,
#    6.133378697763584e-05,
#    7.864439403613475e-05,
#    6.518931610465169e-05,
#    5.7624995454890714e-05,
#    6.561326154042035e-05,
#    5.563519868914266e-05,
#    6.174481991075346e-05,
#    5.895601037643265e-05,
#    6.814857771771247e-05,
#    5.662845251208637e-05,
#    6.162145221791666e-05,
#    5.4649716866093665e-05,
#    5.8302876997449276e-05,
#    6.363764797687837e-05,
#    5.869060116813845e-05,
#    6.302705046533795e-05,
#    6.196511129290113e-05,
#    5.269300848514367e-05,
#    5.117083941165239e-05,
#    5.0650739951301964e-05,
#    5.132129623002293e-05,
#    5.0585952386485435e-05,
#    5.759114046281382e-05,
#    6.122153927014764e-05,
#    5.1507862774590825e-05,
#    5.1199464886597895e-05,
#    5.319972602747123e-05,
#    5.1532502650243647e-05,
#    5.0818691732352e-05,
#    4.987734168838521e-05,
#    5.0750605062584075e-05,
#    5.8147194222522347e-05,
#    5.4776707018274776e-05,
#    5.431003038656274e-05,
#    5.579699462303208e-05,
#    6.03842340654971e-05,
#    6.179117255979168e-05,
#    5.60975364118968e-05,
#    5.316966873695182e-05,
#    5.614853011564342e-05,
#    5.328396783876629e-05,
#    4.8562205383279164e-05,
#    4.688950487414989e-05,
#    4.6014632545770744e-05,
#    5.0379107477133496e-05,
#    4.935173610840835e-05,
#    4.5921959138061715e-05,
#    4.6720715080811445e-05,
#    5.1751427816541646e-05,
#    5.114827039738265e-05,
#    4.574893764003447e-05,
#    4.6150222105813766e-05,
#    5.3080455705020675e-05,
#    5.2781793125719325e-05,
#    4.9785814321404224e-05,
#    4.779272216608738e-05,
#    5.166457521362587e-05,
#    4.607273671779772e-05,
#    4.688061911091357e-05,
#    4.485541625825213e-05,
#    4.5530585145783376e-05,
#    4.8621434464795575e-05,
#    4.874535048618279e-05,
#    4.615246588729589e-05,
#    4.4538669944233064e-05,
#    4.489824378323008e-05,
#    4.49544778019388e-05,
#    4.864577900623269e-05,
#    4.766210475552609e-05,
#    4.8115161800833835e-05,
#    4.833415248945227e-05,
#    4.725203886683882e-05,
#    4.737609510521771e-05,
#    4.845337443452507e-05,
#    4.9206901437967046e-05,
#    4.760464048075014e-05,
#    4.911694219465952e-05,
#    4.5190737318022154e-05,
#    4.6021341791430965e-05,
#    4.431260551543946e-05,
#    4.7062251317758174e-05,
#    4.514860700781239e-05,
#    4.7418234858691616e-05,
#    4.624944797777719e-05,
#    4.487413095008146e-05,
#    4.3544251813263473e-05,
#    4.8575163863790025e-05,
#    4.5273918348879735e-05,
#    4.56720349865599e-05,
#    4.561380139537195e-05,
#    4.532704317287116e-05,
#    4.8013127254423723e-05,
#    4.4726410085283356e-05,
#    4.372045673625643e-05,
#    4.0901174988322694e-05,
#    4.178869517574562e-05,
#    4.417354485919164e-05,
#    4.5922001013519894e-05,
#    4.464397305979374e-05,
#    4.3700559275593866e-05,
#    4.150295756110783e-05,
#    4.145887373368246e-05,
#    4.152556872174907e-05,
#    4.270980582774389e-05,
#    4.317313459010775e-05,
#    4.2639043424563346e-05,
#    4.213601634082226e-05,
#    4.2058867427143965e-05,
#    4.055869415404889e-05,
#    4.396863446442133e-05,
#    4.324410114582242e-05,
#    4.2485963855684296e-05,
#    4.237302500962656e-05,
#    4.228911127435648e-05,
#    4.182316103864689e-05,
#    3.946053882518367e-05,
#    4.2280151474381244e-05,
#    4.305904923889915e-05,
#    4.150693708420186e-05,
#    4.223782606788247e-05,
#    4.3563196316988086e-05,
#    4.0690549870673075e-05,
#    3.936377718073732e-05,
#    4.104268899685307e-05,
#    4.4839369482051165e-05,
#    4.060406725794235e-05,
#    4.160308661936297e-05,
#    4.142120819101655e-05,
#    4.1616675747370226e-05,
#    4.20063813393465e-05,
#    4.043887902492102e-05,
#    3.893718577331883e-05,
#    4.076830605589884e-05,
#    4.182211806108442e-05,
#    3.857665208844528e-05,
#    3.801195557474436e-05,
#    3.8098998010490446e-05,
#    3.977678360125208e-05,
#    4.0993433356832493e-05,
#    4.209213910415085e-05,
#    3.979417132096058e-05,
#    4.186065698957735e-05,
#    4.063264118195412e-05,
#    4.1703484036607986e-05,
#    3.7639650087085295e-05,
#    4.210356854990947e-05,
#    4.161638590882463e-05,
#    3.9827261253834724e-05,
#    4.0844532432334316e-05,
#    3.960484258293055e-05,
#    3.9365169055948155e-05,
#    3.7162105806427016e-05,
#    3.6846251919570856e-05,
#    3.905578457906426e-05,
#    3.891966530608578e-05,
#    4.2260851377579187e-05,
#    4.051905663336003e-05,
#    4.099971529479049e-05,
#    3.934176922794382e-05,
#    3.995684454956914e-05,
#    4.139911103033847e-05,
#    3.7887198599724175e-05,
#    3.672606583271037e-05,
#    3.893205088233833e-05,
#    4.044478009745944e-05,
#    3.9510580733049403e-05,
#    4.111742968466678e-05,
#    3.759111418633999e-05,
#    3.681021564958389e-05,
#    3.8037215416168575e-05,
#    3.907548740786064e-05,
#    3.871233453305359e-05,
#    3.8446857248113415e-05,
#    3.87090619776071e-05,
#    3.88723067172055e-05,
#    3.8464502412875364e-05,
#    3.846378700821314e-05,
#    3.7658085428584526e-05,
#    3.858096026809282e-05,
#    3.7752629376630836e-05,
#    3.5552154200713824e-05,
#    3.764670041260964e-05,
#    3.591975876182179e-05,
#    3.548434959040915e-05,
#    3.5407145565222116e-05,
#    3.8037711884170036e-05,
#    3.70463934659517e-05,
#    3.760122432295441e-05,
#    3.834594079965795e-05,
#    3.7527214327054295e-05,
#    3.870172734790918e-05,
#    3.9867874565583835e-05,
#    3.720696301396411e-05,
#    3.927799340825468e-05,
#    3.7469478132713465e-05,
#    4.035110477490618e-05,
#    3.773112524520021e-05,
#    3.5414349459894395e-05,
#    3.705120438330886e-05,
#    3.6231823771154174e-05,
#    3.4727979854846555e-05,
#    3.582260506710612e-05,
#    3.79060869469887e-05,
#    3.7657499559188974e-05,
#    3.76268235994119e-05,
#    3.439623858557365e-05,
#    3.5244344155913454e-05,
#    3.6052556366639886e-05,
#    4.001625088579764e-05,
#    3.774310201325979e-05,
#    3.678986529926175e-05,
#    3.6161415490378785e-05,
#    3.759059004647846e-05,
#    3.490717697670644e-05,
#    3.69950521804214e-05,
#    3.5594210164569455e-05,
#    3.583204653160523e-05,
#    3.434721165444415e-05,
#    3.520975098310489e-05,
#    3.636918015043657e-05,
#    3.729743021973805e-05,
#    3.5903859168954906e-05],
#   'lin_loss_tr': [0.0010537040386438131,
#    0.0004199871002632055,
#    0.0003461044097809676,
#    0.0003280725997025543,
#    0.0003061340908158293,
#    0.00027929372949887343,
#    0.00027268623686742353,
#    0.000253646511911474,
#    0.0002494806588188983,
#    0.00022368431258500812,
#    0.0002515120922520935,
#    0.0002688043775591761,
#    0.00027184796434742936,
#    0.0003126168661030069,
#    0.0003138212443755424,
#    0.00027266262174073725,
#    0.00026830564023297713,
#    0.0002546765190732487,
#    0.0002666336126338215,
#    0.0003013764198453344,
#    0.00029343029653202703,
#    0.00027882833401623005,
#    0.0002703595299030991,
#    0.0002798368229203798,
#    0.000270173659528348,
#    0.000250452989619473,
#    0.0003049731410314091,
#    0.0003012862496766599,
#    0.00028180475860705323,
#    0.0002538282825163209,
#    0.00025861858878844477,
#    0.00029579880898149605,
#    0.00027638584179704654,
#    0.0002629166246674202,
#    0.00025862115503417604,
#    0.0002567778270879879,
#    0.00026000940929503836,
#    0.0002503558888689595,
#    0.00024628594806888436,
#    0.0002444885020017961,
#    0.00024070564943534184,
#    0.0002518972446039775,
#    0.00024176587984139257,
#    0.00023040532718407623,
#    0.0002310156899298779,
#    0.00022465660623175666,
#    0.00022371941397184545,
#    0.0002537290158525525,
#    0.0002117520075927964,
#    0.00020713384474994257,
#    0.00020059635441631397,
#    0.00019591617084633401,
#    0.00019909709675282122,
#    0.00021002946240069502,
#    0.0002374165998573633,
#    0.00022125260550231535,
#    0.000217244812990836,
#    0.00021511416041980835,
#    0.00023404577393406763,
#    0.00022651746706848846,
#    0.00021053811840519824,
#    0.00020889079810040904,
#    0.00021041120619864816,
#    0.00020804755470809586,
#    0.00020587909223630706,
#    0.00020474613553775038,
#    0.0002016278344176789,
#    0.00021653388474542805,
#    0.00020253648619202182,
#    0.0001980082277131782,
#    0.00018561625465542632,
#    0.00018033592486778828,
#    0.00018046613184467673,
#    0.00017897423652144388,
#    0.00017658339648017105,
#    0.00017370796388391644,
#    0.00018939207276413614,
#    0.00018943375765415345,
#    0.00018554314753620272,
#    0.0002061820936084606,
#    0.00019425654271741378,
#    0.00018735179966167012,
#    0.00018916630026379085,
#    0.0001822122661557861,
#    0.0001811001895978908,
#    0.00018266115821848446,
#    0.00018306866262177442,
#    0.00017858065644333615,
#    0.00018050974687596068,
#    0.00017375101526069672,
#    0.00017029419572320469,
#    0.00017570616035571105,
#    0.00017673531553381064,
#    0.0001739554174994911,
#    0.00017250285848004229,
#    0.00016554116232424696,
#    0.00016297718909125716,
#    0.00016251969274425722,
#    0.0001592443441814852,
#    0.00015685473679579755,
#    0.00016390351401183735,
#    0.00016725762094559266,
#    0.00015680525184700643,
#    0.00015629297032570863,
#    0.00015532654380993026,
#    0.00015819510542527533,
#    0.00015659996395388202,
#    0.00015160880262710827,
#    0.00015248291179267788,
#    0.0001583968565837688,
#    0.00015934233190219334,
#    0.00015827549848720392,
#    0.00016691462231856928,
#    0.00016135700245789114,
#    0.00016113028075469241,
#    0.00016405208480910972,
#    0.00015742060566752,
#    0.00015591433924434588,
#    0.00016056731553188466,
#    0.0001532377235831673,
#    0.00014983729852247052,
#    0.00014928064480587404,
#    0.00015098708311772033,
#    0.00015050051103784464,
#    0.0001481583887962575,
#    0.00014285081031514292,
#    0.0001472756898208977,
#    0.0001498598628151082,
#    0.0001454277438863349,
#    0.00014231731016634705,
#    0.00014689115050714463,
#    0.0001509217228034531,
#    0.0001480224839705191,
#    0.00014697932636679865,
#    0.00014456635719707652,
#    0.00014335782744889544,
#    0.00014345487308790015,
#    0.00013833836613017373,
#    0.00013957167662893163,
#    0.00013967158551206514,
#    0.00014207212425003006,
#    0.0001357576071855642,
#    0.00013446493601882237,
#    0.00013523083853602232,
#    0.0001333982182451167,
#    0.00013690922787645832,
#    0.00013393760982967736,
#    0.0001375491333322877,
#    0.00013751628222885204,
#    0.00013683228810785952,
#    0.0001370238049353344,
#    0.00013489122686726835,
#    0.00013583185833301693,
#    0.0001360203375255917,
#    0.0001367216071694782,
#    0.00013488989915981135,
#    0.00013396080898831877,
#    0.00013466144399841296,
#    0.00013293645439416843,
#    0.00013272919278143548,
#    0.00013157862578853073,
#    0.00013318679633270454,
#    0.0001308958597562989,
#    0.0001289412417037888,
#    0.0001311639724472696,
#    0.00012921041405284184,
#    0.00012844305154508317,
#    0.00012792943341489088,
#    0.0001276310007248886,
#    0.00012987628260236036,
#    0.00013138952643667505,
#    0.0001241253290921103,
#    0.0001243012961919142,
#    0.00012500937489366674,
#    0.00012686767343226128,
#    0.00012897476366599724,
#    0.00012632964670898373,
#    0.00012763346967403777,
#    0.00012144967896598788,
#    0.0001227089620791029,
#    0.00012164379563244515,
#    0.0001229990901923342,
#    0.00012307556878906635,
#    0.00012148271994095573,
#    0.00012144871745592954,
#    0.00012129529963242525,
#    0.0001188645136550049,
#    0.00012106968186228497,
#    0.00012194709818280163,
#    0.00012247321787884737,
#    0.00012022117764300152,
#    0.00011939703720000058,
#    0.00011759041189315155,
#    0.0001167504050635158,
#    0.00011725086679166936,
#    0.0001190884752159423,
#    0.00011725548137427665,
#    0.00011755296130085047,
#    0.00011821487165202308,
#    0.00011630552932942048,
#    0.00011598012938617451,
#    0.00011572563217920648,
#    0.00011708759468982611,
#    0.00011672878254296635,
#    0.00011604575449885661,
#    0.00011662668034563118,
#    0.00011707369118626725,
#    0.0001171575481458468,
#    0.00011447267280210384,
#    0.00011398306370655847,
#    0.00011396954567394556,
#    0.00011280777649285193,
#    0.00011118043248450007,
#    0.00011108143387010638,
#    0.000110469488061697,
#    0.00011157974539797733,
#    0.00011205383448891263,
#    0.00011240721141803078,
#    0.00010992590568035821,
#    0.00011256615587316968,
#    0.00011126588434946941,
#    0.00011154223977157133,
#    0.00011020982407338105,
#    0.00011217967496238688,
#    0.0001122038052887953,
#    0.00011073612698423181,
#    0.00011221731999304462,
#    0.00011125207078913128,
#    0.00010916588817440726,
#    0.00010752321604547645,
#    0.00010766975739240112,
#    0.00010908535888178294,
#    0.0001072312447154508,
#    0.00010811849046768522,
#    0.00010890378720471339,
#    0.00010888297177363246,
#    0.00010948448896747419,
#    0.00011031492729361684,
#    0.00011000868904917065,
#    0.00010694210706130067,
#    0.00010668142900574318,
#    0.00010965631233201303,
#    0.0001079780507852581,
#    0.00010952626217523232,
#    0.00010836623341868077,
#    0.00010583758797865618,
#    0.00010604406092402604,
#    0.00010545696622625172,
#    0.00010656666788062022,
#    0.0001067324648945632,
#    0.00010507768185677978,
#    0.00010389872485130253,
#    0.00010554258427718912,
#    0.00010438130784871434,
#    0.00010601633851926654,
#    0.00010598096188450073,
#    0.00010424101755562971,
#    0.00010427881058236148,
#    0.00010232782632885302,
#    0.00010249700844337411,
#    0.00010228393550781394,
#    0.00010152226442438947,
#    0.00010048988677110484,
#    0.00010139033985708127,
#    9.975361396580875e-05,
#    0.00010108950370154839,
#    0.00010210643000739746,
#    0.00010138313952298399,
#    0.00010327223486804523,
#    0.00010022880923451282,
#    0.00010090493494917222,
#    0.0001023523264906389,
#    0.00010061578320752969,
#    0.00010402784151820208,
#    0.00010375163734313397,
#    9.960617349629212e-05,
#    0.00010138551868372002,
#    9.918980821508895e-05,
#    9.829660554347124e-05,
#    0.0001002022952579477,
#    0.00010056842206432386,
#    0.00010047808439381658,
#    9.933158822179316e-05,
#    9.862421041148952e-05,
#    9.88955848987779e-05,
#    9.916544606428633e-05,
#    0.00010030797397546926,
#    0.00010115893313381326,
#    0.00010006568303884086,
#    0.00010076479574831381,
#    9.862175361473767e-05,
#    9.752979631810647e-05,
#    9.95561600343245e-05,
#    9.819065637705708e-05,
#    9.779340944852323e-05,
#    9.823452513801191e-05,
#    9.617866925645046e-05,
#    9.66447241421036e-05,
#    9.93592921270434e-05,
#    9.752183332432438e-05],
#   'pred_loss_tr': [0.002242340581204267,
#    0.0018619997773636529,
#    0.0015197922871943484,
#    0.001455312252956185,
#    0.0013915363716536222,
#    0.0013450059006882317,
#    0.0012500550990498208,
#    0.0012011745395981014,
#    0.0012021814398665695,
#    0.0010630218349298106,
#    0.0009895135986648421,
#    0.0009523112137375915,
#    0.0007419132000885586,
#    0.000816188067472738,
#    0.0007562085421399233,
#    0.0008150255939170242,
#    0.0007812887141629657,
#    0.000746231763301655,
#    0.0007352369680797602,
#    0.0005818405971946591,
#    0.0005274712311802432,
#    0.0005126444767154951,
#    0.0004870189772423436,
#    0.0005505054135202489,
#    0.0006814519819020829,
#    0.0006115386102155366,
#    0.0006054159225351078,
#    0.0005252576381106802,
#    0.0006155878038546863,
#    0.0005901128461118788,
#    0.0005741569812984225,
#    0.00043328020578012506,
#    0.00038398984210327903,
#    0.00034724186828478856,
#    0.0003671713146762526,
#    0.0003548125391813649,
#    0.0003835707252716368,
#    0.00033149845709905344,
#    0.00034079639435537716,
#    0.0003811560628162895,
#    0.0003413541661699283,
#    0.00037654339610797136,
#    0.00034369896426103373,
#    0.00030994548495150506,
#    0.00031245412801001024,
#    0.00031767995592127456,
#    0.0003255755749550906,
#    0.00046672384617503417,
#    0.00042048411132975856,
#    0.0003969621441470697,
#    0.0003900756459420626,
#    0.00039733506096997594,
#    0.0003930268782262809,
#    0.0003604649583452401,
#    0.0003770695461463084,
#    0.00029012894238087723,
#    0.0002840029916656699,
#    0.0003225722305595558,
#    0.0003130944353463921,
#    0.0002792620447159626,
#    0.0002800962471891135,
#    0.0002870173329745043,
#    0.00027020207074956293,
#    0.00030637635667362506,
#    0.00025577766791684553,
#    0.00027993603865244485,
#    0.00026665257532744013,
#    0.0003202814691479595,
#    0.0002690255665158397,
#    0.0003529396691443795,
#    0.0003384929932121366,
#    0.00034457372338634896,
#    0.00033577692343858366,
#    0.00034838197879775605,
#    0.0003336238968334696,
#    0.00033620465453961825,
#    0.0003111877599718703,
#    0.0002522440969342108,
#    0.0002534785417857223,
#    0.000291868273826425,
#    0.0002560665638389145,
#    0.00023299317244697916,
#    0.00024670902627242847,
#    0.0002248715934408036,
#    0.00024275890981253394,
#    0.00023196882830234244,
#    0.0002624113400630217,
#    0.0002262545460054869,
#    0.00024477985921003757,
#    0.000217238355346242,
#    0.00022891569019424076,
#    0.00022629563225448092,
#    0.00021772379129307662,
#    0.00022137779857036956,
#    0.00023850884045191863,
#    0.0002558975323521968,
#    0.0002533667736335043,
#    0.00025154761657331814,
#    0.0002539271869302846,
#    0.00024455743798480783,
#    0.00022568936788531496,
#    0.00024670817219885066,
#    0.0002487627487503329,
#    0.00024337918922414092,
#    0.0002480668020112678,
#    0.0002453513075027892,
#    0.00024474986523583014,
#    0.0002416286083740836,
#    0.00024015072762886895,
#    0.0002020129839830259,
#    0.00019558065260037225,
#    0.0001955807061638049,
#    0.0002323075804792523,
#    0.00021619066745265725,
#    0.0002212024092899655,
#    0.0002016630297727348,
#    0.00019957054524987123,
#    0.00021522155525707738,
#    0.0002222245337257033,
#    0.0002374499790095526,
#    0.00022961334972468979,
#    0.00019704744393474104,
#    0.0001817514432254842,
#    0.0002036049120354793,
#    0.0001967040771752239,
#    0.0001959982419453383,
#    0.00018844474687555588,
#    0.000191860222486789,
#    0.00019326697223190654,
#    0.0001953518906102932,
#    0.00019107421618908585,
#    0.00018064152963949922,
#    0.00016480674937756316,
#    0.00016032382739061352,
#    0.00018295823866402373,
#    0.00019772445112392503,
#    0.00019180980644763467,
#    0.00019366331361333266,
#    0.00018249270996943293,
#    0.0001607520118457305,
#    0.0001673731787880744,
#    0.00019815445820642438,
#    0.00019030676133858853,
#    0.0001865449934136469,
#    0.00019242473648231913,
#    0.00016520302914556096,
#    0.00019599403133318622,
#    0.00017022046271681864,
#    0.00018001273317767822,
#    0.0001640230336906438,
#    0.00015732838476245154,
#    0.00017439903108715178,
#    0.00017207037594647425,
#    0.00015501094047918896,
#    0.00016197433170089695,
#    0.00014926137590280517,
#    0.0001725016732729892,
#    0.00014965649670363958,
#    0.00015898550268599485,
#    0.00015080876332928148,
#    0.00016258884599974795,
#    0.000148760172801013,
#    0.00015764226539412195,
#    0.00017041627189486307,
#    0.00017082171178388193,
#    0.00015271189972446202,
#    0.0001526803752448301,
#    0.0001582789201997815,
#    0.0001561091874541586,
#    0.00015838640799901963,
#    0.00015016254172301258,
#    0.00018094553370053503,
#    0.0001746517675123772,
#    0.00017598782095716315,
#    0.00015840076640473698,
#    0.0001561752180079682,
#    0.00017036074116712118,
#    0.0001576829688038994,
#    0.000174418688866934,
#    0.00017893197884327394,
#    0.0001706679161524083,
#    0.00013842333638867206,
#    0.00013612926944760865,
#    0.00015374990115115577,
#    0.0001418744437576103,
#    0.00015429616387143354,
#    0.00014908122025093342,
#    0.00014532537015645388,
#    0.00013897414820793859,
#    0.00012905734462386115,
#    0.00013719690515303073,
#    0.00014963586077198108,
#    0.00015457203505533508,
#    0.00014923416227325203,
#    0.00014351872178327115,
#    0.0001336351370481041,
#    0.00015344011603218028,
#    0.00014367247770659308,
#    0.00013090331234939475,
#    0.0001280710906591613,
#    0.00014956828756034968,
#    0.00015211478045997902,
#    0.00013377709492875086,
#    0.00015246618730746744,
#    0.00013571685655946604,
#    0.0001283695236587788,
#    0.0001328671889805651,
#    0.00012923871327075176,
#    0.0001338559540794875,
#    0.0001446910476822287,
#    0.0001343383262289361,
#    0.00014619410935568902,
#    0.000146666499665329,
#    0.00014201286173007015,
#    0.00014565585104022867,
#    0.00014019300230776278,
#    0.0001348078388973397,
#    0.00013226624968352708,
#    0.00014314897124038793,
#    0.00013461038341777934,
#    0.00014895510948337418,
#    0.00014128280568872877,
#    0.00013943351571450623,
#    0.00013224011312791225,
#    0.0001304566388345383,
#    0.00014452861301214533,
#    0.00013562861451955929,
#    0.00012612813968208936,
#    0.00013943309394117602,
#    0.00014324092912732902,
#    0.00014126458506538294,
#    0.00012826725148268916,
#    0.0001361475511425561,
#    0.00014485125157466912,
#    0.0001420475538829936,
#    0.00014156335686145232,
#    0.0001450640157464535,
#    0.00014156408515384798,
#    0.00012738390982354139,
#    0.00014509388726784234,
#    0.00013549154592762167,
#    0.0001306789407031016,
#    0.00012761572508408905,
#    0.00012795561664499976,
#    0.00012484175385907292,
#    0.0001380817208902296,
#    0.00012489642114737665,
#    0.00012429887484610477,
#    0.00013544753884606837,
#    0.00012555083873287893,
#    0.00012473094063758988,
#    0.0001333598463153318,
#    0.00012697797075738793,
#    0.00012398497703078977,
#    0.00013897973792367376,
#    0.00011850676294651497,
#    0.00012710839957357978,
#    0.00013645149614448918,
#    0.00013916625222067368,
#    0.00011801471965612863,
#    0.00013604728109327125,
#    0.00013643242338266066,
#    0.0001392065426811546,
#    0.00013553229577968176,
#    0.00014078531680849102,
#    0.00012644898657875254,
#    0.00012514241841037144,
#    0.00014100233486115418,
#    0.00012463527611466718,
#    0.00013659308024216443,
#    0.00013554480717581835,
#    0.00014186160494338108,
#    0.00013769383711289575,
#    0.00013742308936421166,
#    0.00012133553498139744,
#    0.00014040093617253698,
#    0.00012221637982602648,
#    0.00013921094688022152,
#    0.00013693657471795884,
#    0.00012822768892758487,
#    0.00012232961060053253,
#    0.00012178959212256,
#    0.00013090425559215526,
#    0.00013327867875093634,
#    0.00013470244626427922,
#    0.00012497068204770875,
#    0.00012688023003221965,
#    0.0001290802002644186,
#    0.00011529684947008525,
#    0.0001171185598495674,
#    0.00011982654169959789,
#    0.00013342413311623571,
#    0.0001261438361673735,
#    0.00011385184784848341,
#    0.0001348958254272881,
#    0.00013969545916745816,
#    0.00013379624857755496,
#    0.0001254406650990317,
#    0.00011972442905274913,
#    0.00013414001094791641],
#   'total_loss_tr': [0.04317209114657437,
#    0.02470307729821256,
#    0.020332468554694602,
#    0.01933821558238978,
#    0.018131748218327127,
#    0.017415191433293387,
#    0.01617550992585243,
#    0.015422928791017608,
#    0.014942565724808485,
#    0.013292963249965551,
#    0.012800373493673954,
#    0.011885910958765036,
#    0.0094160449621763,
#    0.010516119234145005,
#    0.009414811242134013,
#    0.009865960819607085,
#    0.00949680708606351,
#    0.009058678488029128,
#    0.009183884741976223,
#    0.00749572912884995,
#    0.006851359389405301,
#    0.00664141119279443,
#    0.006340139064977461,
#    0.007276717786419582,
#    0.008426165936435474,
#    0.007571643376921086,
#    0.007909576621580315,
#    0.006891644104047024,
#    0.008048320734041168,
#    0.007275932934135199,
#    0.007286664673147049,
#    0.005901302126771275,
#    0.0052759841758203,
#    0.004798658769280511,
#    0.0050125524768249155,
#    0.004919924701445122,
#    0.005288955497931927,
#    0.004612419216774721,
#    0.00473468741055261,
#    0.00524980108689596,
#    0.004756845085524973,
#    0.005228084549208746,
#    0.004789985847619778,
#    0.004329386724535614,
#    0.004389507188263567,
#    0.004447836852434309,
#    0.0045710371490171615,
#    0.00618525622709793,
#    0.0054115572983914235,
#    0.005128839454474918,
#    0.005051467436405414,
#    0.005150860611428606,
#    0.00509416962418943,
#    0.004905130731516537,
#    0.005255777443303389,
#    0.004109414891300208,
#    0.004016777988463799,
#    0.004585236546266427,
#    0.004524327460379201,
#    0.003955971875644111,
#    0.0039631269842465506,
#    0.004041719926580628,
#    0.0038222864399010195,
#    0.004285760065342517,
#    0.003655068375705246,
#    0.00399742462236355,
#    0.0037623249152873425,
#    0.00454392119191904,
#    0.003828866627721235,
#    0.004680335452344189,
#    0.004409315034826385,
#    0.00448959912520219,
#    0.0044052566555229595,
#    0.004527348284411462,
#    0.00436172724770818,
#    0.004406821554863548,
#    0.004281583504672063,
#    0.0036221430265404126,
#    0.0036042384020587865,
#    0.004202141840149589,
#    0.003685477434934929,
#    0.003358247989610313,
#    0.0035814270501005204,
#    0.003245472873343115,
#    0.0034875013330515395,
#    0.003346873969929491,
#    0.003750550493776323,
#    0.003260988764405409,
#    0.003504327760930074,
#    0.003139079231372539,
#    0.0032895207107859724,
#    0.003336838667003557,
#    0.0031986787563506912,
#    0.003271188921334737,
#    0.003432481628941729,
#    0.0035010451361774764,
#    0.00344485883660456,
#    0.003418693487393729,
#    0.003448940513833882,
#    0.0033396017128363886,
#    0.0032449954887852073,
#    0.003508388840078198,
#    0.003396635691813649,
#    0.003334743837687246,
#    0.003399223512771757,
#    0.003356627832622604,
#    0.0033422867232497703,
#    0.003296638489700854,
#    0.0032920971156117766,
#    0.003011445425688586,
#    0.0029008681539129067,
#    0.002897194524771197,
#    0.0033059766778643146,
#    0.0031847253223841496,
#    0.0032327109179954897,
#    0.002983636032056777,
#    0.0029172520450455076,
#    0.003102740711294749,
#    0.0031627916255371367,
#    0.0032363706441754674,
#    0.003135514371295242,
#    0.002796961441685624,
#    0.0026931989804266933,
#    0.0029097703097269254,
#    0.002790185870563096,
#    0.0027882507804067847,
#    0.0027721592973164737,
#    0.0028024650862480097,
#    0.002749746536558613,
#    0.0027724736385007806,
#    0.0028099177796591787,
#    0.0027119917621677542,
#    0.002508277301379341,
#    0.0024438621240985047,
#    0.0027110762398769245,
#    0.002793158937067269,
#    0.002742596693891794,
#    0.002734179043785689,
#    0.0026321050468237793,
#    0.002450103210186229,
#    0.002530080892958064,
#    0.002793356487676105,
#    0.0026923761779858555,
#    0.002659180692020566,
#    0.002721691301013244,
#    0.002485314978564039,
#    0.002803692371247614,
#    0.002532713983376372,
#    0.002637060137435873,
#    0.0024920445334344625,
#    0.002397360468402188,
#    0.002574487979414853,
#    0.0025575748406984704,
#    0.0023727863816484967,
#    0.0024570821006683276,
#    0.0022870289369862763,
#    0.0025276450286718442,
#    0.0022830090676236184,
#    0.002405088441941808,
#    0.002299949115617795,
#    0.0024456371506180693,
#    0.0022888267858627628,
#    0.0023578904479979834,
#    0.0024683360280369983,
#    0.0025319124428317586,
#    0.002315864105649451,
#    0.002318176766609813,
#    0.0023709088303842285,
#    0.002341743494245283,
#    0.0023951091137318376,
#    0.002281697522700229,
#    0.0025692915152560206,
#    0.0024752635087699013,
#    0.0024963261638867094,
#    0.0023564178994460467,
#    0.002355520998652866,
#    0.0024734638752713007,
#    0.0023396874436157496,
#    0.002476954407880994,
#    0.002519304322901162,
#    0.0024335239679512985,
#    0.002130734428337359,
#    0.0021127706983106883,
#    0.00228154387181387,
#    0.002153674913372131,
#    0.002274656754997658,
#    0.0022040879269665543,
#    0.0022131278764139463,
#    0.0021428208961646925,
#    0.0020363082207660093,
#    0.0021073342811197358,
#    0.002236811221240366,
#    0.002272008336149156,
#    0.0021887133356203584,
#    0.0021667187052600563,
#    0.0020795087032812708,
#    0.0022545427262307483,
#    0.002163643026080458,
#    0.0020509565848500486,
#    0.001988899533666591,
#    0.002192356556832315,
#    0.0022356339539599387,
#    0.002092423483461855,
#    0.0022349317652232787,
#    0.002074446664142244,
#    0.001999934545737949,
#    0.002053552603180659,
#    0.002017698507072364,
#    0.00204475487314878,
#    0.002130367642050569,
#    0.0020510061331925557,
#    0.002176349768365555,
#    0.002145423449853316,
#    0.0020930009418504035,
#    0.002128350391161648,
#    0.0020982080320035047,
#    0.002057549932555474,
#    0.002040649018686344,
#    0.0021216672538046507,
#    0.0020628867861616643,
#    0.0021986050266237494,
#    0.002128775979570569,
#    0.0020596111351822285,
#    0.002042785870218451,
#    0.002015460800240807,
#    0.002138954271473228,
#    0.002057150449663242,
#    0.0019504600142604335,
#    0.0020748502512938005,
#    0.002090276128543105,
#    0.0020646768711269537,
#    0.0019635564555968853,
#    0.0020344243521128406,
#    0.002174786487693324,
#    0.002118172360574232,
#    0.002112639150235485,
#    0.0021297821943509453,
#    0.0021061073342199498,
#    0.0019761326343831704,
#    0.0021152194041976747,
#    0.0020048128814991327,
#    0.0019886419028440055,
#    0.0019732252063051343,
#    0.001962940795644325,
#    0.0019530385913466043,
#    0.002039506643802482,
#    0.0018978882630533995,
#    0.0019038962324130092,
#    0.0020275897373683116,
#    0.001940115768601127,
#    0.001913485016941311,
#    0.0020060176463262674,
#    0.0019431066639879918,
#    0.0019092465047427314,
#    0.002063383413924578,
#    0.0018411109749069238,
#    0.00194347792978775,
#    0.0020198431262310516,
#    0.0020222484711260396,
#    0.0018338043133708391,
#    0.001991882792703728,
#    0.0019915027685086938,
#    0.0020155815031141677,
#    0.002010247950006197,
#    0.002055044923760393,
#    0.00191752536053908,
#    0.0019124583712719538,
#    0.002060720775068361,
#    0.0019138316088851462,
#    0.002042957083718415,
#    0.0020026783223580967,
#    0.0020891597823913585,
#    0.0020232951872922638,
#    0.002056387017798075,
#    0.0018671276444133292,
#    0.0020298503049490774,
#    0.0018624645766821947,
#    0.002022462717425871,
#    0.001981666243506318,
#    0.0019079521930023553,
#    0.0018732703533618058,
#    0.0018679119406287816,
#    0.001956933978053325,
#    0.0019436765640498475,
#    0.001965769014242006,
#    0.0018756837061447824,
#    0.001948071524817893,
#    0.001938504516147077,
#    0.0017926601056465284,
#    0.0018013692708646364,
#    0.001840669731114139,
#    0.0019470129404811467,
#    0.001900588144904914,
#    0.0017600674813791635,
#    0.001978896964499925,
#    0.002006342048766686,
#    0.0019531873007740904,
#    0.001879511136026617,
#    0.0018391996545300997,
#    0.001969628497968091],
#   'recon_loss_va': [3.6372784658548575e-05,
#    5.071170501954233e-05,
#    4.378523378060587e-05,
#    5.6065223361656535e-05,
#    4.798535792360781e-05,
#    8.854279318863216e-05,
#    4.206880354710544e-05,
#    8.651259243682337e-05,
#    5.118440549267689e-05,
#    7.879999672392539e-05,
#    6.817028042860329e-05,
#    4.688338928341788e-05,
#    6.010774783741605e-05,
#    5.637901934581654e-05,
#    4.5527969026200786e-05,
#    5.9318911250253827e-05,
#    4.774667862269174e-05,
#    4.5815561861672904e-05,
#    4.522392282524379e-05,
#    4.0516333683626726e-05,
#    4.707508681652447e-05,
#    4.293985815214304e-05,
#    5.6323692660953384e-05,
#    5.739273698660933e-05,
#    4.66441430641377e-05,
#    4.2701158842343524e-05,
#    6.987678837807228e-05,
#    6.0934331183185954e-05,
#    3.8920425443696636e-05,
#    4.0630834215941526e-05,
#    9.808259649920122e-05,
#    5.878536588473556e-05,
#    3.632818394786833e-05,
#    3.933788987827332e-05,
#    3.8054559809097555e-05,
#    4.386310229165247e-05,
#    4.642120226587091e-05,
#    4.085888940608129e-05,
#    3.94918303451656e-05,
#    4.276530580682447e-05,
#    4.7097254234055676e-05,
#    3.858218011979867e-05,
#    4.117797167661289e-05,
#    4.425398522774534e-05,
#    3.8486184469851047e-05,
#    3.359677915189726e-05,
#    0.00010638654991150058,
#    4.405795940935301e-05,
#    3.6364360918620754e-05,
#    3.3650894238235196e-05,
#    3.594746037075917e-05,
#    3.7931279318096735e-05,
#    4.209471262583975e-05,
#    5.0679749013700835e-05,
#    5.633475514817595e-05,
#    4.0735163565841503e-05,
#    6.0174721208265204e-05,
#    4.428803943786382e-05,
#    4.0285276554641314e-05,
#    3.758189207777226e-05,
#    3.629603088484146e-05,
#    3.243593376585826e-05,
#    3.290157716643686e-05,
#    3.419439356851702e-05,
#    4.0327025696266595e-05,
#    3.2147128725531125e-05,
#    3.415809199699046e-05,
#    4.290399889820643e-05,
#    3.42242383339908e-05,
#    2.9259752864163602e-05,
#    3.2140625535248546e-05,
#    3.741650107258465e-05,
#    2.931980285817796e-05,
#    3.3629584777372656e-05,
#    3.5914042200602125e-05,
#    3.0478894738431943e-05,
#    3.3749457846473284e-05,
#    3.3159184264756426e-05,
#    6.469284138195992e-05,
#    5.0950463749662354e-05,
#    3.871430878158814e-05,
#    2.8781508262909483e-05,
#    3.158821831069266e-05,
#    2.9043508523803514e-05,
#    3.0471267412697973e-05,
#    4.102863264658178e-05,
#    3.0986622277850984e-05,
#    4.414129458988706e-05,
#    3.073884984890659e-05,
#    3.5393032097393494e-05,
#    5.220050267477442e-05,
#    3.620482372449866e-05,
#    2.7092641327423433e-05,
#    3.179400012716845e-05,
#    2.986198675595612e-05,
#    2.801146350369284e-05,
#    2.6246384247012127e-05,
#    2.7751519458737068e-05,
#    2.6463895665074233e-05,
#    2.707770606017827e-05,
#    3.966574937900683e-05,
#    4.3611669752863236e-05,
#    2.736577713828107e-05,
#    2.8273782087732496e-05,
#    3.4474208102134675e-05,
#    2.494508862582734e-05,
#    2.5957350771932397e-05,
#    2.941070397355361e-05,
#    2.7614465276807703e-05,
#    2.999885312722957e-05,
#    2.9852145871700486e-05,
#    2.9472164442267967e-05,
#    3.2594029410878043e-05,
#    5.4722784625482745e-05,
#    2.9419372367556207e-05,
#    2.796658054649015e-05,
#    2.9248923207584692e-05,
#    2.8056893521958653e-05,
#    3.1083418889465975e-05,
#    2.406996372883441e-05,
#    2.497768400644418e-05,
#    2.5991633719968377e-05,
#    2.8108805205799097e-05,
#    2.404710918805601e-05,
#    2.3302040366009653e-05,
#    2.572033630106792e-05,
#    3.275288948619467e-05,
#    2.491573089476636e-05,
#    2.606377195964645e-05,
#    2.459936088901789e-05,
#    2.7035817765863612e-05,
#    2.7333014259056654e-05,
#    2.4785233563306974e-05,
#    2.6753381007438293e-05,
#    3.618290156737203e-05,
#    2.3796153072908055e-05,
#    2.3755400737475913e-05,
#    2.3304263171060786e-05,
#    3.3234069330016304e-05,
#    3.0154064158220233e-05,
#    2.44534953708353e-05,
#    2.1960747138412746e-05,
#    2.411622532842254e-05,
#    2.244830496541302e-05,
#    2.636510301575375e-05,
#    2.9091106777438352e-05,
#    2.3708471871941583e-05,
#    2.4340675433146924e-05,
#    2.181074023610563e-05,
#    2.5176525620433193e-05,
#    2.532702562045112e-05,
#    2.714342523783368e-05,
#    3.9747549029319394e-05,
#    2.2550391501378424e-05,
#    2.241888902669113e-05,
#    2.283495086885523e-05,
#    2.6380940198578173e-05,
#    2.227414552180562e-05,
#    2.6043435354949906e-05,
#    2.445666056397992e-05,
#    2.4291221355573118e-05,
#    2.634908620772573e-05,
#    2.4037191148333175e-05,
#    2.5247391325441033e-05,
#    2.2012848755063413e-05,
#    2.4030250642681494e-05,
#    3.3974955537511654e-05,
#    2.2702061566330183e-05,
#    4.101567355974112e-05,
#    2.226411606898182e-05,
#    2.363827237180279e-05,
#    2.1373259793714777e-05,
#    2.1532542026155472e-05,
#    2.2270192099919466e-05,
#    2.7613650824302265e-05,
#    2.3443052668881137e-05,
#    2.1307672492791124e-05,
#    2.2927778748756584e-05,
#    2.0344050578084232e-05,
#    2.0938946060293045e-05,
#    2.2396973993939657e-05,
#    2.250212234381858e-05,
#    2.0488442714849953e-05,
#    1.9731588812040474e-05,
#    2.2570215908975417e-05,
#    2.242615937575465e-05,
#    2.1160715884131303e-05,
#    2.4874570499378024e-05,
#    2.2196931089032052e-05,
#    2.1830375620387105e-05,
#    2.4602728141568757e-05,
#    2.1331349065197475e-05,
#    2.077028875646647e-05,
#    1.930714870468364e-05,
#    2.360604094064911e-05,
#    2.954923775178031e-05,
#    2.1827091889766354e-05,
#    2.573545195142894e-05,
#    2.1068968938683003e-05,
#    2.2745867227058625e-05,
#    1.8983411943433264e-05,
#    2.577455416030716e-05,
#    2.4071417556115193e-05,
#    2.002469773287885e-05,
#    2.1478744656633353e-05,
#    2.444785756476146e-05,
#    1.8995134572226863e-05,
#    2.4627273736162653e-05,
#    2.0564879226488603e-05,
#    2.326871557064199e-05,
#    2.06692695125336e-05,
#    1.9728050422903227e-05,
#    1.9999963266551884e-05,
#    1.9453552492147235e-05,
#    2.0187225497162824e-05,
#    2.09595458121233e-05,
#    2.024341786939961e-05,
#    2.1338693083331844e-05,
#    2.497365858289413e-05,
#    1.93871533156198e-05,
#    3.0209603210096247e-05,
#    1.9391407628669793e-05,
#    2.1520913075316155e-05,
#    2.7041441474769574e-05,
#    2.1599678651303595e-05,
#    1.887826814102785e-05,
#    2.2354509989478782e-05,
#    2.035715260717552e-05,
#    2.014625670199166e-05,
#    1.924476449251718e-05,
#    2.1408164987709217e-05,
#    2.0472448795771925e-05,
#    2.9859896888713895e-05,
#    1.900640169575733e-05,
#    2.177991458059599e-05,
#    3.5701973198835425e-05,
#    2.4331166362874985e-05,
#    1.8581517451821128e-05,
#    2.0406951231658848e-05,
#    1.8412608975874416e-05,
#    1.9608897370441507e-05,
#    2.1091251862041343e-05,
#    2.5608787685390173e-05,
#    2.115451343343011e-05,
#    2.2399615166553605e-05,
#    1.939255101509237e-05,
#    1.880955263307745e-05,
#    2.6113438252650667e-05,
#    1.860218829582057e-05,
#    2.0121450082418352e-05,
#    2.072093957394827e-05,
#    1.967390107893152e-05,
#    2.6055603332982475e-05,
#    1.876441623001786e-05,
#    2.1126943768952817e-05,
#    1.8340080411386832e-05,
#    2.0339626037942555e-05,
#    2.0672427126555704e-05,
#    1.9377878288651118e-05,
#    1.956424830495962e-05,
#    1.8051483645346405e-05,
#    1.9439805328147486e-05,
#    2.0255449423226917e-05,
#    2.079147452604957e-05,
#    1.7991038172719225e-05,
#    2.252021082919479e-05,
#    2.39240122634025e-05,
#    1.9857337974826805e-05,
#    2.212733185539643e-05,
#    1.8311002804694e-05,
#    1.780813173960875e-05,
#    2.516942974276996e-05,
#    1.84904467156836e-05,
#    1.9919204078178154e-05,
#    1.862884634344179e-05,
#    1.927009528420361e-05,
#    2.0892591692245333e-05,
#    1.8395694193410843e-05,
#    1.7760836347709603e-05,
#    1.8391360602739344e-05,
#    1.9751453540569248e-05,
#    1.996273886106792e-05,
#    1.7997929035118432e-05,
#    1.8200831770324537e-05,
#    1.7826877410698216e-05,
#    2.4844104700605385e-05,
#    2.174804315776176e-05,
#    2.175711188101559e-05,
#    2.1142885240503045e-05,
#    2.2569870604153646e-05,
#    2.016870560813307e-05,
#    2.6036175919822806e-05,
#    1.7780159396352246e-05,
#    1.8633450811951963e-05,
#    2.0743095774378162e-05,
#    1.7428462418441388e-05,
#    1.7744772018583415e-05,
#    2.16961998376064e-05,
#    2.854923892906906e-05,
#    1.7478076870247605e-05],
#   'lin_loss_va': [0.00027229687839280814,
#    0.0002871684288644853,
#    0.00019544173119356856,
#    0.00020508599724659385,
#    0.00017381407330200696,
#    0.00023139319212835593,
#    0.00015630704001523554,
#    0.00015302667573754056,
#    0.00012188390428491402,
#    0.00011844396552381416,
#    0.00014419807363689566,
#    0.00017744684858674495,
#    0.00014628356560327424,
#    0.0001907943284701711,
#    0.00013441741672674348,
#    0.00013617520016850904,
#    0.00022159476793603972,
#    0.00013831205372601593,
#    0.00013768436110694893,
#    0.00022301484326211116,
#    0.0001826076598566336,
#    0.00017198413843289018,
#    0.0001606445063468224,
#    0.00014439302018824188,
#    0.00014083474707149435,
#    0.00016914022247268198,
#    0.0001852669459670627,
#    0.00018163551552182375,
#    0.0001811460084960951,
#    0.00012121887023871143,
#    0.0003422488104358005,
#    0.00024391077507364875,
#    0.00016821938819096735,
#    0.00014611720932104313,
#    0.00015280682843391938,
#    0.00013241684609965887,
#    0.00018739065853878856,
#    0.00014814963590955207,
#    0.00014511868660823288,
#    0.00014743877666963576,
#    0.00019514311134116724,
#    0.00012469495110660014,
#    0.00014185149302647915,
#    0.00015263812686801734,
#    0.00016398748630308546,
#    0.00014454437647752152,
#    0.00017068970191758126,
#    0.0001412091508730858,
#    0.00013046626433303268,
#    0.00012298658293730114,
#    0.0001116097258394196,
#    0.00014027485849510413,
#    0.00010493888112250715,
#    0.00020574803905522762,
#    0.0001511875288997544,
#    0.00013696878886548802,
#    0.00011984901902906131,
#    0.0001508853317015261,
#    0.00011458169986629703,
#    0.00013188906814320944,
#    0.0001243334742563699,
#    0.0001267938672147769,
#    0.0001260801024424533,
#    0.00015589087039794927,
#    0.00012063076853034242,
#    0.00013216783554526046,
#    0.0001806129548640456,
#    0.00011533170133285846,
# ...
#    5.582145149674034e-05,
#    6.349069311302931e-05,
#    6.304237558651948e-05,
#    5.6501706239941996e-05,
#    5.820185378979659e-05,
#    5.409679124568356e-05,
#    5.6153067816921975e-05,
#    5.8814091062231455e-05,
#    6.303775717242388e-05,
#    6.969665658592324e-05,
#    5.7177794891079735e-05,
#    6.328771026649822e-05,
#    5.989526289340574e-05,
#    5.737810928015582e-05],
#   'pred_loss_va': [0.0019161065671748172,
#    0.0014982120289156835,
#    0.0013695114272801827,
#    0.0013284568849485368,
#    0.0012892347488862772,
#    0.001474077997651572,
#    0.0012029828697753449,
#    0.0011168030323460698,
#    0.001236520940437913,
#    0.0009737938671605662,
#    0.0007935473889422914,
#    0.0007359846398079147,
#    0.0006374051348151019,
#    0.0006434747095530232,
#    0.0007724813719202454,
#    0.0005973267567848476,
#    0.0006998350824384639,
#    0.0008734146249480546,
#    0.0005712465669300096,
#    0.00044920122551654157,
#    0.00038618772183932987,
#    0.0003695615960168652,
#    0.00042094670061487705,
#    0.0005630257122296219,
#    0.000378759791298459,
#    0.0003241850778673931,
#    0.00043503567576408386,
#    0.0007927833988408869,
#    0.0004863817909305605,
#    0.0006812305752343187,
#    0.0003404019056082082,
#    0.00027419766653717187,
#    0.00027764779224526137,
#    0.00025861311830036965,
#    0.00026868159329751506,
#    0.00027358055012882687,
#    0.00030422732258254354,
#    0.00025197740736378665,
#    0.00022209955932339653,
#    0.00024378477367766513,
#    0.00040902641679470736,
#    0.0003118722913010667,
#    0.00022099611305748112,
#    0.00025948816861879703,
#    0.00021647909185655104,
#    0.00023372876845921078,
#    0.0005371496372390538,
#    0.00030972827031898004,
#    0.00041075419236828264,
#    0.0002280125227116514,
#    0.0002873251020597915,
#    0.00031864019062292453,
#    0.0002596847601428938,
#    0.0004677462614684676,
#    0.00022670012670763148,
#    0.0002193794631845473,
#    0.0002734279526824442,
#    0.00019914763712828668,
#    0.00027649772649359267,
#    0.00017718738793822317,
#    0.0001738499995553866,
#    0.00019939596071102036,
#    0.00019571237620160295,
#    0.00019294345717450292,
#    0.00026160883984024014,
#    0.00017500194007880054,
#    0.0003171337957610376,
#    0.00018334214473725297,
#    0.00017828211396893798,
#    0.0002713600224524271,
#    0.0003660383639119876,
#    0.00024335740454262123,
#    0.0002448303857818246,
#    0.00033852129369430867,
#    0.0002732820939854719,
#    0.0002520696507417597,
#    0.00016031587316926257,
#    0.00019671505773051953,
#    0.000276872063598906,
#    0.00023600705996310958,
#    0.00019426430299063213,
#    0.0001524019899079576,
#    0.000168849378193651,
#    0.00015625637570337858,
#    0.0001556871150872515,
#    0.00020567404135363176,
#    0.00018101779642165639,
#    0.0002318558921009147,
#    0.0001624973701837007,
#    0.00021987672153045423,
#    0.0001825490859725202,
#    0.00013700955241802149,
#    0.00012062417348109496,
#    0.0001734602301439736,
#    0.00029012452917716775,
#    0.00022846100667569166,
#    0.00025436936630285345,
#    0.00020419576685526408,
#    0.00018895017759253582,
#    0.00016575673968569996,
#    0.0001689666375265612,
#    0.00015527637454700502,
#    0.00017666752561732815,
#    0.00020242394142163297,
#    0.00018879364870372228,
#    0.00019326577360819405,
#    0.00023494188159626597,
#    0.0001608159885411927,
#    0.00012553465906724645,
#    0.0001579629576250833,
#    0.00017158579430542886,
#    0.00013138234862708487,
#    0.00011992923464276828,
#    0.00018270115833729506,
#    0.00016231979134317953,
#    0.00013898490154436635,
#    0.00023830250453708382,
#    0.000155190291479812,
#    0.00012285383551594956,
#    0.00017317475552166192,
#    0.00020154145386186428,
#    0.00012441239838760035,
#    0.0001411233370163245,
#    0.00014340514826471917,
#    0.00018500519945519045,
#    0.00010096273338907243,
#    0.00015166228331509046,
#    0.00013239349573268555,
#    0.00014678439038107172,
#    0.00016354132458218373,
#    0.00010283506586953688,
#    0.00010998447275293681,
#    0.00011983291248422272,
#    0.00010230425687041134,
#    0.00012234797880713208,
#    0.00012614524166565388,
#    0.00023238679326217002,
#    0.00011561979348092184,
#    0.00012943254781324262,
#    0.00017992108890515132,
#    0.00014460758211498614,
#    0.00010542264438602918,
#    0.0001696638428256847,
#    0.00019785765228637805,
#    0.00012149721745421023,
#    0.00012422309434138393,
#    0.00013960773988704508,
#    0.00010896616064807556,
#    0.00014446897997307437,
#    0.00012281611998332664,
#    0.00014600610241662557,
#    0.00010333168938814197,
#    0.00014980752287859408,
#    0.00011366057879058644,
#    0.0001169249208032852,
#    9.711350503494032e-05,
#    0.00013074242633592803,
#    0.00011509370718461771,
#    0.0001152012179469845,
#    0.0001352574005674493,
#    0.00012176035124866758,
#    0.0001164377863460686,
#    0.00012344106107775588,
#    0.00019434699424891733,
#    0.00011843928829572785,
#    0.00011689502328711872,
#    0.00012191919328567262,
#    0.0001173300267206893,
#    0.00018557395257327394,
#    0.00010471747555129696,
#    8.453387120728924e-05,
#    0.00010136907440028153,
#    0.00013439781711592028,
#    0.00017681114331935532,
#    0.00015129529432063768,
#    0.00011730405640264507,
#    9.514252997178119e-05,
#    0.000130967925239626,
#    0.00010714249826075199,
#    0.00018727093993220478,
#    9.954572427280557e-05,
#    0.00011104935886881624,
#    9.688339863108315e-05,
#    0.00010477289227613558,
#    7.581325159359646e-05,
#    9.920972115651239e-05,
#    0.0001225764802560055,
#    0.00010725935680966359,
#    8.235377875583556e-05,
#    9.189492751223345e-05,
#    0.00014476481313370945,
#    0.00011313826325931586,
#    0.00013248640971141867,
#    0.0001252098615320089,
#    7.822164267660507e-05,
#    0.00011904050976833484,
#    0.0001452448996133171,
#    0.0001118780249574532,
#    9.35394958408627e-05,
#    8.871627990932514e-05,
#    7.867634121794254e-05,
#    0.00010745196777861565,
#    8.143942159222206e-05,
#    0.0001266904134051098,
#    8.12691854055932e-05,
#    9.405636653051867e-05,
#    8.495938921745012e-05,
#    7.987401295395102e-05,
#    9.653089728089981e-05,
#    8.515181373998833e-05,
#    0.00010706651119107846,
#    0.00010202484615244127,
#    0.0001221530067899342,
#    8.226887045263236e-05,
#    9.702584611659404e-05,
#    0.00011419944591276969,
#    8.343657858252602e-05,
#    0.00011404526776459534,
#    0.00011852208990603685,
#    6.972078911834008e-05,
#    0.00011958482779543071,
#    9.800746677986656e-05,
#    8.701127323244388e-05,
#    8.152604217078381e-05,
#    8.228985128274265e-05,
#    0.00011053140709312477,
#    7.941229644832977e-05,
#    7.551947237516288e-05,
#    7.663193567471656e-05,
#    0.00010623493350673623,
#    9.155308604628469e-05,
#    0.00011018003594169083,
#    0.00012585561974750212,
#    7.830513974719604e-05,
#    8.7333385332992e-05,
#    0.00012472155807093563,
#    0.0001303089860205849,
#    8.085147510428214e-05,
#    9.719721007665309e-05,
#    6.833187126176199e-05,
#    7.258283130795462e-05,
#    8.505500045430381e-05,
#    8.784831394829477e-05,
#    0.00012203468880519115,
#    8.229465584008722e-05,
#    8.891828050157831e-05,
#    6.726694239963156e-05,
#    8.561759811224572e-05,
#    7.179850429868868e-05,
#    7.904877111286623e-05,
#    9.211102648502371e-05,
#    7.257938189771569e-05,
#    7.991449638211634e-05,
#    7.313930776338869e-05,
#    7.452186764567159e-05,
#    7.23373059372534e-05,
#    9.043184036272578e-05,
#    8.34946334483296e-05,
#    9.384652063696801e-05,
#    7.672479932807619e-05,
#    9.27262008190155e-05,
#    0.00012592295085293395,
#    7.156418572170271e-05,
#    0.0001226695840159664,
#    9.161373903528632e-05,
#    8.902309612797883e-05,
#    0.00015176369743130635,
#    7.361767984548351e-05,
#    8.444152020577651e-05,
#    8.024986103312888e-05,
#    6.854207761837945e-05,
#    8.249931791700267e-05,
#    6.629262406931957e-05,
#    8.095872362900991e-05,
#    0.00012381861476266445,
#    0.00010907406067417469,
#    7.484728970060435e-05,
#    0.0001317779260716634,
#    8.269940675139272e-05,
#    6.969174773985287e-05,
#    6.821884865833756e-05,
#    7.330308653763495e-05,
#    8.560746027796995e-05,
#    0.00010364597013297801,
#    0.00013080061034997925,
#    7.459170713749093e-05,
#    0.00011252272937175196,
#    7.068786332335246e-05,
#    6.377554260931599e-05,
#    8.64689003113502e-05,
#    7.286606523848604e-05,
#    9.08288548089331e-05,
#    0.00011579836367066794,
#    7.676606613434463e-05,
#    9.48718855700766e-05,
#    0.0001255712140846299,
#    6.350163979125985e-05,
#    7.937993571734599e-05,
#    9.626445413838762e-05,
#    9.205610876961146e-05],
#   'total_loss_va': [0.01979709044098854,
#    0.015776405887057383,
#    0.014328408210227886,
#    0.014050307140375176,
#    0.013546015213554105,
#    0.01585760115024944,
#    0.012606823816895485,
#    0.012186182740454873,
#    0.012998937473942837,
#    0.010644382797181606,
#    0.008761374745517969,
#    0.008006127124341825,
#    0.007121412587972979,
#    0.0071893314986179275,
#    0.008314510768589875,
#    0.00670263198359559,
#    0.007697412627749145,
#    0.009330613926673928,
#    0.006302389161040385,
#    0.0051201904425397515,
#    0.004515235758541773,
#    0.004296998648593823,
#    0.004933348468815287,
#    0.006348577599662046,
#    0.004394874015512566,
#    0.003838002604121963,
#    0.005234391467335324,
#    0.00871881276058654,
#    0.005434168153442442,
#    0.007339832799819608,
#    0.004727093813320001,
#    0.003573741162351022,
#    0.0033079791658868394,
#    0.003125627195307364,
#    0.003220168272188554,
#    0.00330685346852988,
#    0.0036938758372950056,
#    0.003076512618766477,
#    0.0027610326069407165,
#    0.0030129396085006497,
#    0.004756379794950287,
#    0.003629239664102594,
#    0.0027635923276344934,
#    0.003190059680491686,
#    0.0027136402398658297,
#    0.0028177998416746655,
#    0.006606051581911743,
#    0.0036790714560387037,
#    0.004601651763853927,
#    0.0027396207636532686,
#    0.003344335282842318,
#    0.0037059895306204758,
#    0.003122733576068034,
#    0.005390008135388295,
#    0.0029815363426071904,
#    0.0027381150090756514,
#    0.0034558757906779647,
#    0.0025852421143402657,
#    0.0032824117224663496,
#    0.0022795818998323134,
#    0.002225793791391576,
#    0.002445112836236755,
#    0.00241221960944434,
#    0.0024272693747965,
#    0.003139989469976475,
#    0.002203658523891742,
#    0.0036935318688241145,
#    0.0023777931152532497,
#    0.002251121390145272,
#    0.0031170949223451316,
#    0.004092226561624557,
#    0.002903789204234878,
#    0.0028430576203390956,
#    0.0038178972511862717,
#    0.0032192758905390897,
#    0.0029267279508834085,
#    0.0020462199463509023,
#    0.002401365937354664,
#    0.0035667569027282298,
#    0.0030050082908322415,
#    0.0024419385396565,
#    0.0019181290602621932,
#    0.002109706877187515,
#    0.0019602389947976917,
#    0.001959637137285123,
#    0.002560172831484427,
#    0.002225317138557633,
#    0.0028622730751521885,
#    0.0020364870821746686,
#    0.002654859893179188,
#    0.0024474135328394673,
#    0.0018492558156140149,
#    0.0015915054051826398,
#    0.002148913510609418,
#    0.0032970442747076354,
#    0.002654613616565863,
#    0.002906637169265499,
#    0.002417166600935161,
#    0.0022437699954025447,
#    0.002021321541784952,
#    0.0022020227528021983,
#    0.0020782870318119726,
#    0.002143831089294205,
#    0.0023963195853866637,
#    0.002324430999578908,
#    0.0022718893790928027,
#    0.00270381736724327,
#    0.0019924415294857076,
#    0.001662074859874944,
#    0.001965902600204572,
#    0.002117879184273382,
#    0.0017100511759053916,
#    0.0016263552048864465,
#    0.002466248484173169,
#    0.002017795651530226,
#    0.0017697566848558683,
#    0.002759658459884425,
#    0.0019271468142202746,
#    0.0016178482619579881,
#    0.0020557951065711677,
#    0.002350023055138687,
#    0.0015935694488386314,
#    0.0017875424042964976,
#    0.0017639385478105396,
#    0.0021670041605830193,
#    0.001345758782311653,
#    0.001933926958978797,
#    0.0016506047977600247,
#    0.001807635814960425,
#    0.0019690073774351427,
#    0.0014199408954785515,
#    0.0014757200260646641,
#    0.0015341411053668708,
#    0.001376145868562162,
#    0.0016748435931125034,
#    0.001580017318095391,
#    0.0026446361637984714,
#    0.0014799601146175216,
#    0.0017153291070523362,
#    0.002177957173747321,
#    0.0017800957915217925,
#    0.0013525299436878413,
#    0.0020108872752947113,
#    0.0022866767443095646,
#    0.0015542769203117739,
#    0.0016175259564382334,
#    0.0017088476452045143,
#    0.0014125758898444474,
#    0.0017426161308928083,
#    0.0015635571132103603,
#    0.001798569515813142,
#    0.0013962510662774246,
#    0.0019707259295197823,
#    0.0014364897991375376,
#    0.001474344734257708,
#    0.0012741067912429571,
#    0.0016522046935278922,
#    0.0014556961444516976,
#    0.0014810154680162668,
#    0.0016721811164946605,
#    0.0015323857175341498,
#    0.0015033615539626528,
#    0.001556968578370288,
#    0.002284514184187477,
#    0.0014710191171616316,
#    0.0014819316177939375,
#    0.0016346901732807357,
#    0.001477659980688865,
#    0.0023435784387402236,
#    0.0013413590204436332,
#    0.0011502975345744442,
#    0.0013018909085076302,
#    0.0016300015170903255,
#    0.002055866333345572,
#    0.001864551236697783,
#    0.0014712796740544338,
#    0.0012473040987970307,
#    0.0016137434092039864,
#    0.0013446694744440417,
#    0.002153181645553559,
#    0.001291239052079618,
#    0.0014094672612069796,
#    0.0012462809633386012,
#    0.0013169808468470972,
#    0.00106001185971157,
#    0.0012894907073738675,
#    0.0015088808237730216,
#    0.0013854852392493437,
#    0.0011215263366466388,
#    0.0012119816383346915,
#    0.0017777024574267368,
#    0.0014156667166389525,
#    0.0016080401837825775,
#    0.001517065519389386,
#    0.0010886340023716912,
#    0.0015499162254855037,
#    0.0017380783683620393,
#    0.0014507197580921154,
#    0.0012152007111581042,
#    0.00118285767287792,
#    0.001042553568064856,
#    0.0013955226653100301,
#    0.0011231064951668184,
#    0.0015379797550849617,
#    0.0010951519216177985,
#    0.0012480432390778635,
#    0.001112202318230023,
#    0.001112889503322852,
#    0.0012362545433764656,
#    0.001149880272957186,
#    0.001345755095826462,
#    0.001280599448364228,
#    0.0014878639776725322,
#    0.0010800213155259069,
#    0.0012355343496892601,
#    0.0014116760188092787,
#    0.0011033079693637167,
#    0.0014202968741301447,
#    0.0014957345071403931,
#    0.0009617851707541073,
#    0.0015662104124203324,
#    0.001241024729097262,
#    0.001148197256649534,
#    0.0011465978604974225,
#    0.0011051425875242178,
#    0.0013605641627994676,
#    0.0010793925806259115,
#    0.0010260278068017215,
#    0.001032615575240925,
#    0.0013170175176734726,
#    0.0011901202281781782,
#    0.0013763857714366168,
#    0.001618499916124468,
#    0.0010405013017589226,
#    0.0011589323112275451,
#    0.0016741727110153686,
#    0.0016075222811196,
#    0.0010577594706167777,
#    0.001239903048068906,
#    0.0009329680469818413,
#    0.0009817744188088302,
#    0.0011314095512110118,
#    0.0011965200974373147,
#    0.0014900667786908646,
#    0.0011078176612500101,
#    0.0011466686943701159,
#    0.0009205169675018018,
#    0.0011817458386455353,
#    0.0009632719835887352,
#    0.0010510207212064415,
#    0.0011890787573065609,
#    0.0009838340726370614,
#    0.001121881995156097,
#    0.0009809255085807915,
#    0.0010250060052688543,
#    0.0009761970868567005,
#    0.001178275269921869,
#    0.0011023421441980947,
#    0.0012012770360646148,
#    0.0010267953669729952,
#    0.001165658201595458,
#    0.0015102580073289573,
#    0.000974699558961826,
#    0.001493732415838167,
#    0.0011520721648897354,
#    0.0011704244146433969,
#    0.0018246210044405113,
#    0.0009946236532414332,
#    0.001125651605737706,
#    0.0010457009290500234,
#    0.0009214713500114158,
#    0.0011320946359774098,
#    0.0009107464041638499,
#    0.0010693775354108463,
#    0.0014876872786165525,
#    0.001340853525713707,
#    0.001016438700996029,
#    0.00155821637599729,
#    0.001066460211101609,
#    0.0009444063374151787,
#    0.0009365443887266641,
#    0.000993812849628739,
#    0.001095888083606648,
#    0.001277117165348803,
#    0.0015435603369648259,
#    0.0010562264408993844,
#    0.001398529188008979,
#    0.000987940453342162,
#    0.000912226668636625,
#    0.0011468894372228533,
#    0.0009885495625591527,
#    0.0012227471112661685,
#    0.0013919383151611935,
#    0.0010128092690138146,
#    0.0012191875866847113,
#    0.0014996934138859312,
#    0.0008696419099578634,
#    0.001074049054295756,
#    0.001308032195083797,
#    0.00115271996279868]})

# %%
trainer.test_KoopmanAE(test_loader)
# Out:
# Test - Recon Loss: 1.880918e-05, Linear Loss: 6.137397e-05, Pred Loss: 8.975030e-05, Total Loss: 1.146969e-03

# %% [markdown]
# ## Visualization
#
# Visualize the original, reconstructed, and predicted trajectories from the test set.

# %%
# for saving the results first

# Get a test sample
traj = preprocessed_data["Xtest"][5].to(device)

# Get reconstructed trajectory
model.eval()
with torch.no_grad():
    Y, reconstructed_traj = model.ae(traj)


# Get predicted trajectory
predicted_traj = trainer.predict_new(X0=traj[0], steps=len(traj)-1)

# Convert to numpy for plotting
traj = traj.cpu().detach().numpy()
reconstructed_traj = reconstructed_traj.cpu().detach().numpy()
predicted_traj = predicted_traj.cpu().detach().numpy()

# Plot trajectories
plot_trajectories(traj[:,:3], predicted_traj[:,:3], reconstructed_traj[:,:3], folder_path=folder_path,save=True)
plot_trajectory_comparison(traj, predicted_traj, reconstructed_traj, folder_path=folder_path,save=True)

# %%
# Get a test sample
traj = preprocessed_data["Xtest"][3].to(device)

# Get reconstructed trajectory
model.eval()
with torch.no_grad():
    Y, reconstructed_traj = model.ae(traj)


# Get predicted trajectory
predicted_traj = trainer.predict_new(X0=traj[0], steps=len(traj)-1)

# Convert to numpy for plotting
traj = traj.cpu().detach().numpy()
reconstructed_traj = reconstructed_traj.cpu().detach().numpy()
predicted_traj = predicted_traj.cpu().detach().numpy()

# Plot trajectories
plot_trajectories(traj[:,:3], predicted_traj[:,:3], reconstructed_traj[:,:3], folder_path=folder_path,save=False)
plot_trajectory_comparison(traj, predicted_traj, reconstructed_traj, folder_path=folder_path,save=False)

# %% [markdown]
# ## Eigenvalues Visualization
#
# Compute and visualize the eigenvalues of the Koopman operator on a unit circle.

# %%
# Compute eigenvalues
eigenvalues, eigenvectors = torch.linalg.eig(model.knet.net.weight)
eigenvalues = eigenvalues.cpu().detach().numpy()
idx = np.argsort(eigenvalues.real)[::-1]
eigenvalues = eigenvalues[idx]

# Print eigenvalues
print('Eigenvalues:')
print(eigenvalues)

# Plot eigenvalues on unit circle
plot_eigenvalues_on_unit_circle(eigenvalues, folder_path)

print(f"Training and evaluation completed. Results saved in {folder_path}")
# Out:
# Eigenvalues:
# [ 1.0010929 -0.08188859j  1.0010929 +0.08188859j  0.9938247 +0.01944565j
#   0.9938247 -0.01944565j  0.9875219 +0.j          0.9750156 -0.1572809j
#   0.9750156 +0.1572809j   0.96196806-0.23847671j  0.96196806+0.23847671j
#   0.89299625-0.4398079j   0.89299625+0.4398079j   0.8008124 -0.594806j
#   0.8008124 +0.594806j    0.77289224-0.6310208j   0.77289224+0.6310208j
#   0.72593427+0.6845343j   0.72593427-0.6845343j   0.6360407 -0.7689082j
#   0.6360407 +0.7689082j   0.5721855 -0.8181486j   0.5721855 +0.8181486j
#   0.49512827-0.8672077j   0.49512827+0.8672077j   0.37689975-0.92446667j
#   0.37689975+0.92446667j  0.26315713-0.96288085j  0.26315713+0.96288085j
#   0.05335743-0.9971951j   0.05335743+0.9971951j  -0.00731104-0.9986296j
#  -0.00731104+0.9986296j  -0.13204494+0.98915195j -0.13204494-0.98915195j
#  -0.18862209-0.980502j   -0.18862209+0.980502j   -0.24312615-0.9683763j
#  -0.24312615+0.9683763j  -0.37531927-0.925215j   -0.37531927+0.925215j
#  -0.4937476 -0.86807895j -0.4937476 +0.86807895j -0.55410725-0.83074915j
#  -0.55410725+0.83074915j -0.60298735-0.7959959j  -0.60298735+0.7959959j
#  -0.6609658 -0.7486557j  -0.6609658 +0.7486557j  -0.75989807+0.6479078j
#  -0.75989807-0.6479078j  -0.8068234 -0.5881256j  -0.8068234 +0.5881256j
#  -0.88453114-0.46328416j -0.88453114+0.46328416j -0.93295956-0.35547984j
#  -0.93295956+0.35547984j -0.9364155 -0.345253j   -0.9364155 +0.345253j
#  -0.9745848 -0.21785504j -0.9745848 +0.21785504j -0.98677707-0.15085776j
#  -0.98677707+0.15085776j -0.9972036 -0.05020966j -0.9972036 +0.05020966j
#  -0.99871945+0.j        ]
# Training and evaluation completed. Results saved in experiments/isolated_repressilator_200_time_steps_64_bottleneck_higher_sampling

# %%
violin_plot(model, preprocessed_data["Xtest"], device, folder_path)

# %% [markdown]
# ### Long Term Prediction on the Repressilator

# %%
from utils.data_loader import RepressilatorModel

#y = [15, 20, 80,  90, 30, 70]
y = np.random.rand(6) * 100
#y = y = [70, 10, 3,  65, 12, 3]
print('Initial conditions:', y)
Repressilator_model = RepressilatorModel(y0=y)

parameters = Repressilator_model.suggested_parameters()
times =  np.linspace(0,100, 1001)
traj = Repressilator_model.simulate(parameters, times)

traj = traj/data_handler.Xscale
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from utils.data_loader import RepressilatorModel
#       3 #y = [15, 20, 80,  90, 30, 70]
#       4 y = np.random.rand(6) * 100
#
# ModuleNotFoundError: No module named 'utils'

# %%
# visualize each dimension 

plt.figure(figsize=(10, 6))
plt.plot(times, traj[:, 0], label='x1', color='blue')
plt.plot(times, traj[:, 1], label='x2', color='orange')
plt.plot(times, traj[:, 2], label='x3', color='green')
plt.plot(times, traj[:, 3], label='x4', color='red')
plt.plot(times, traj[:, 4], label='x5', color='purple')
plt.plot(times, traj[:, 5], label='x6', color='brown')
plt.xlabel('Time')
plt.ylabel('Values')
plt.title('Repressilator Model Simulation')
plt.legend()
plt.grid()
plt.show()

# %%
# traj as tensor
traj = torch.tensor(traj, dtype=torch.float32).to(device)

# Get reconstructed trajectory
model.eval()
with torch.no_grad():
    Y, reconstructed_traj = model.ae(traj)


# Get predicted trajectory
predicted_traj = trainer.predict_new(X0=traj[0], steps=len(traj)-1)

# Convert to numpy for plotting
traj = traj.cpu().detach().numpy()
reconstructed_traj = reconstructed_traj.cpu().detach().numpy()
predicted_traj = predicted_traj.cpu().detach().numpy()

# Plot trajectories
plot_trajectories(traj[:,:3], predicted_traj[:,:3], reconstructed_traj[:,:3], folder_path=folder_path,save=False)
plot_trajectory_comparison(traj, predicted_traj, reconstructed_traj, folder_path=folder_path,save=False)
